# %% [markdown]
# ## Instalar librerías SQLite3

# %%
# %%shell
# sudo apt-get install sqlite3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# sqlite3 is already the newest version (3.37.2-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %% [markdown]
# ## Crear la base de datos y una tabla de inventario

# %%
import sqlite3

# Crear la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %%
# Crear tabla inventario
c.execute("""
CREATE TABLE IF NOT EXISTS inventario (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)
""")

conn.commit()
conn.close()

# %%
import sqlite3
import random

def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

productos = [generar_producto(i + 1) for i in range(10000)]

conn = sqlite3.connect('productos.db')
c = conn.cursor()

c.executemany("""
INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
VALUES (?, ?, ?, ?, ?, ?, ?)""", productos)

conn.commit()
conn.close()

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# ## Consulta para mostrar todos los productos creados

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# (1, 'Objeto1', 'Electrónica', 258.28, 83, 'Proveedor3', '2023-05-10', 'Almacén A')
# (2, 'Objeto2', 'Hogar', 239.48, 40, 'Proveedor3', '2023-05-27', 'Almacén C')
# (3, 'Artículo3', 'Deportes', 150.91, 38, 'Proveedor3', '2023-02-07', 'Almacén C')
# (4, 'Objeto4', 'Moda', 200.99, 36, 'Proveedor1', '2023-10-24', 'Almacén C')
# (5, 'Objeto5', 'Electrónica', 27.01, 98, 'Proveedor2', '2023-08-05', 'Almacén C')
# (6, 'Producto6', 'Moda', 386.16, 80, 'Proveedor3', '2023-05-09', 'Almacén B')
# (7, 'Producto7', 'Jardín', 349.73, 99, 'Proveedor1', '2023-08-20', 'Almacén B')
# (8, 'Producto8', 'Deportes', 116.11, 37, 'Proveedor2', '2023-01-05', 'Almacén A')
# (9, 'Artículo9', 'Jardín', 226.15, 87, 'Proveedor2', '2023-03-14', 'Almacén C')
# (10, 'Producto10', 'Jardín', 428.99, 36, 'Proveedor1', '2023-05-23', 'Almacén C')
# (11, 'Artículo11', 'Electrónica', 149.9, 17, 'Proveedor3', '2023-09-10', 'Almacén B')
# (12, 'Artículo12', 'Hogar', 479.09, 78, 'Proveedor3', '2023-06-27', 'Almacén B')
# (13, 'Producto13', 'Deportes', 22.7, 49, 'Proveedor2', '2023-03-16', 'Almacén A')
# (14, 'Producto14', 'Jardín', 212.7, 31, 'Proveedor2', '2023-03-22', 'Almacén A')
# (15, 'Producto15', 'Deportes', 170.03, 51, 'Proveedor2', '2023-01-10', 'Almacén A')
# (16, 'Artículo16', 'Electrónica', 42.65, 25, 'Proveedor3', '2023-04-19', 'Almacén B')
# (17, 'Objeto17', 'Jardín', 454.36, 50, 'Proveedor2', '2023-07-01', 'Almacén A')
# (18, 'Producto18', 'Electrónica', 33.17, 47, 'Proveedor3', '2023-03-06', 'Almacén A')
# (19, 'Artículo19', 'Moda', 71.08, 49, 'Proveedor3', '2023-01-14', 'Almacén A')
# (20, 'Producto20', 'Hogar', 223.87, 31, 'Proveedor1', '2023-01-19', 'Almacén C')
# (21, 'Objeto21', 'Jardín', 135.05, 28, 'Proveedor1', '2023-10-05', 'Almacén B')
# (22, 'Objeto22', 'Jardín', 273.04, 44, 'Proveedor1', '2023-04-23', 'Almacén B')
# (23, 'Producto23', 'Hogar', 469, 81, 'Proveedor1', '2023-03-18', 'Almacén C')
# (24, 'Objeto24', 'Jardín', 126.04, 15, 'Proveedor1', '2023-09-24', 'Almacén A')
# (25, 'Objeto25', 'Moda', 256.09, 52, 'Proveedor2', '2023-02-04', 'Almacén C')
# (26, 'Artículo26', 'Deportes', 347.93, 63, 'Proveedor1', '2023-05-11', 'Almacén A')
# (27, 'Artículo27', 'Electrónica', 332.84, 95, 'Proveedor3', '2023-07-15', 'Almacén B')
# (28, 'Artículo28', 'Moda', 261.8, 41, 'Proveedor3', '2023-11-10', 'Almacén C')
# (29, 'Producto29', 'Deportes', 297.16, 26, 'Proveedor2', '2023-04-18', 'Almacén C')
# (30, 'Producto30', 'Jardín', 288.66, 6, 'Proveedor2', '2023-10-12', 'Almacén A')
# (31, 'Objeto31', 'Hogar', 428.01, 86, 'Proveedor3', '2023-02-21', 'Almacén B')
# (32, 'Artículo32', 'Hogar', 412.28, 17, 'Proveedor3', '2023-12-05', 'Almacén C')
# (33, 'Producto33', 'Jardín', 350.92, 68, 'Proveedor2', '2023-02-23', 'Almacén C')
# (34, 'Objeto34', 'Deportes', 365.08, 89, 'Proveedor1', '2023-10-14', 'Almacén A')
# (35, 'Artículo35', 'Moda', 246.86, 84, 'Proveedor1', '2023-10-19', 'Almacén B')
# (36, 'Artículo36', 'Moda', 459.7, 56, 'Proveedor2', '2023-06-13', 'Almacén A')
# (37, 'Producto37', 'Moda', 490.09, 41, 'Proveedor3', '2023-01-23', 'Almacén C')
# (38, 'Producto38', 'Moda', 431.35, 95, 'Proveedor2', '2023-06-05', 'Almacén C')
# (39, 'Producto39', 'Deportes', 368.46, 78, 'Proveedor3', '2023-07-01', 'Almacén C')
# (40, 'Objeto40', 'Deportes', 84.35, 61, 'Proveedor1', '2023-11-14', 'Almacén B')
# (41, 'Objeto41', 'Deportes', 443.76, 61, 'Proveedor1', '2023-09-25', 'Almacén C')
# (42, 'Objeto42', 'Jardín', 218.25, 10, 'Proveedor2', '2023-05-01', 'Almacén A')
# (43, 'Artículo43', 'Moda', 360.81, 42, 'Proveedor2', '2023-12-01', 'Almacén C')
# (44, 'Objeto44', 'Moda', 55.14, 13, 'Proveedor2', '2023-03-04', 'Almacén B')
# (45, 'Artículo45', 'Deportes', 284.06, 75, 'Proveedor1', '2023-07-28', 'Almacén C')
# (46, 'Artículo46', 'Hogar', 136.47, 57, 'Proveedor3', '2023-04-05', 'Almacén C')
# (47, 'Objeto47', 'Moda', 202.82, 30, 'Proveedor1', '2023-08-23', 'Almacén B')
# (48, 'Producto48', 'Jardín', 276.63, 72, 'Proveedor1', '2023-06-07', 'Almacén C')
# (49, 'Objeto49', 'Electrónica', 438.5, 61, 'Proveedor1', '2023-11-15', 'Almacén A')
# (50, 'Artículo50', 'Hogar', 383.61, 2, 'Proveedor2', '2023-03-27', 'Almacén B')
# (51, 'Artículo51', 'Jardín', 314.95, 61, 'Proveedor2', '2023-01-24', 'Almacén C')
# (52, 'Objeto52', 'Deportes', 387.48, 97, 'Proveedor3', '2023-09-08', 'Almacén B')
# (53, 'Objeto53', 'Jardín', 447.91, 26, 'Proveedor2', '2023-10-21', 'Almacén A')
# (54, 'Objeto54', 'Hogar', 300.86, 18, 'Proveedor1', '2023-03-05', 'Almacén C')
# (55, 'Objeto55', 'Electrónica', 333.92, 17, 'Proveedor2', '2023-09-05', 'Almacén B')
# (56, 'Artículo56', 'Deportes', 147.23, 12, 'Proveedor3', '2023-06-12', 'Almacén A')
# (57, 'Artículo57', 'Hogar', 462.27, 88, 'Proveedor1', '2023-09-11', 'Almacén C')
# (58, 'Objeto58', 'Electrónica', 188.28, 6, 'Proveedor3', '2023-01-21', 'Almacén C')
# (59, 'Artículo59', 'Deportes', 419.09, 22, 'Proveedor3', '2023-03-26', 'Almacén A')
# (60, 'Artículo60', 'Jardín', 451.17, 66, 'Proveedor2', '2023-09-10', 'Almacén B')
# (61, 'Artículo61', 'Hogar', 135.16, 47, 'Proveedor3', '2023-09-10', 'Almacén B')
# (62, 'Objeto62', 'Jardín', 414.39, 40, 'Proveedor2', '2023-08-26', 'Almacén A')
# (63, 'Producto63', 'Jardín', 88.42, 10, 'Proveedor2', '2023-12-24', 'Almacén B')
# (64, 'Producto64', 'Hogar', 153.13, 73, 'Proveedor1', '2023-09-04', 'Almacén B')
# (65, 'Artículo65', 'Jardín', 388.3, 37, 'Proveedor1', '2023-06-11', 'Almacén B')
# (66, 'Objeto66', 'Deportes', 395.24, 65, 'Proveedor1', '2023-10-01', 'Almacén C')
# (67, 'Producto67', 'Jardín', 252.22, 56, 'Proveedor1', '2023-03-15', 'Almacén A')
# (68, 'Objeto68', 'Electrónica', 212.8, 64, 'Proveedor1', '2023-04-10', 'Almacén B')
# (69, 'Artículo69', 'Electrónica', 379.11, 20, 'Proveedor1', '2023-11-07', 'Almacén A')
# (70, 'Artículo70', 'Deportes', 270.52, 23, 'Proveedor2', '2023-02-19', 'Almacén B')
# (71, 'Producto71', 'Electrónica', 493.7, 51, 'Proveedor3', '2023-10-02', 'Almacén B')
# (72, 'Producto72', 'Electrónica', 389.57, 90, 'Proveedor3', '2023-07-09', 'Almacén B')
# (73, 'Artículo73', 'Jardín', 361.67, 74, 'Proveedor2', '2023-02-20', 'Almacén A')
# (74, 'Artículo74', 'Hogar', 493.95, 39, 'Proveedor3', '2023-08-01', 'Almacén B')
# (75, 'Artículo75', 'Hogar', 47.09, 30, 'Proveedor1', '2023-04-06', 'Almacén B')
# (76, 'Objeto76', 'Hogar', 145.35, 55, 'Proveedor1', '2023-07-07', 'Almacén B')
# (77, 'Objeto77', 'Moda', 187.87, 89, 'Proveedor1', '2023-01-12', 'Almacén C')
# (78, 'Producto78', 'Hogar', 92.09, 77, 'Proveedor1', '2023-03-08', 'Almacén A')
# (79, 'Objeto79', 'Hogar', 14.11, 45, 'Proveedor2', '2023-05-03', 'Almacén B')
# (80, 'Producto80', 'Jardín', 360.42, 61, 'Proveedor3', '2023-03-10', 'Almacén B')
# (81, 'Producto81', 'Hogar', 46.89, 31, 'Proveedor3', '2023-09-11', 'Almacén A')
# (82, 'Objeto82', 'Deportes', 259.89, 97, 'Proveedor2', '2023-11-25', 'Almacén B')
# (83, 'Objeto83', 'Moda', 471.36, 17, 'Proveedor3', '2023-05-05', 'Almacén A')
# (84, 'Producto84', 'Moda', 400.62, 25, 'Proveedor3', '2023-06-12', 'Almacén C')
# (85, 'Artículo85', 'Hogar', 297.67, 4, 'Proveedor1', '2023-11-28', 'Almacén C')
# (86, 'Artículo86', 'Electrónica', 424, 46, 'Proveedor3', '2023-05-04', 'Almacén B')
# (87, 'Producto87', 'Jardín', 202.13, 53, 'Proveedor1', '2023-08-23', 'Almacén B')
# (88, 'Artículo88', 'Electrónica', 361.15, 30, 'Proveedor1', '2023-01-20', 'Almacén C')
# (89, 'Artículo89', 'Moda', 342.4, 30, 'Proveedor2', '2023-03-01', 'Almacén C')
# (90, 'Producto90', 'Moda', 139.04, 10, 'Proveedor2', '2023-08-12', 'Almacén A')
# (91, 'Objeto91', 'Moda', 15.92, 67, 'Proveedor2', '2023-10-11', 'Almacén C')
# (92, 'Objeto92', 'Deportes', 53.12, 90, 'Proveedor2', '2023-05-02', 'Almacén A')
# (93, 'Producto93', 'Deportes', 86.75, 98, 'Proveedor1', '2023-10-18', 'Almacén A')
# (94, 'Artículo94', 'Deportes', 376.12, 64, 'Proveedor3', '2023-12-15', 'Almacén C')
# (95, 'Artículo95', 'Deportes', 36.19, 5, 'Proveedor1', '2023-06-24', 'Almacén B')
# (96, 'Producto96', 'Electrónica', 444.8, 25, 'Proveedor3', '2023-05-27', 'Almacén A')
# (97, 'Producto97', 'Jardín', 126.91, 39, 'Proveedor3', '2023-03-01', 'Almacén B')
# (98, 'Objeto98', 'Moda', 377.84, 85, 'Proveedor1', '2023-05-07', 'Almacén A')
# (99, 'Objeto99', 'Moda', 250.34, 30, 'Proveedor2', '2023-09-08', 'Almacén C')
# (100, 'Producto100', 'Electrónica', 91.57, 39, 'Proveedor2', '2023-09-27', 'Almacén B')
# (101, 'Artículo101', 'Deportes', 206.8, 41, 'Proveedor3', '2023-10-05', 'Almacén C')
# (102, 'Artículo102', 'Moda', 423.51, 53, 'Proveedor3', '2023-12-26', 'Almacén C')
# (103, 'Artículo103', 'Hogar', 75.54, 7, 'Proveedor2', '2023-04-26', 'Almacén A')
# (104, 'Producto104', 'Jardín', 408.58, 74, 'Proveedor3', '2023-11-25', 'Almacén A')
# (105, 'Objeto105', 'Jardín', 245.5, 19, 'Proveedor2', '2023-03-15', 'Almacén C')
# (106, 'Objeto106', 'Deportes', 223.44, 56, 'Proveedor1', '2023-05-08', 'Almacén C')
# (107, 'Producto107', 'Hogar', 414.11, 48, 'Proveedor1', '2023-07-05', 'Almacén C')
# (108, 'Artículo108', 'Deportes', 146.95, 100, 'Proveedor3', '2023-02-26', 'Almacén A')
# (109, 'Producto109', 'Deportes', 45.96, 88, 'Proveedor3', '2023-01-07', 'Almacén C')
# (110, 'Artículo110', 'Electrónica', 405.76, 5, 'Proveedor1', '2023-01-02', 'Almacén B')
# (111, 'Objeto111', 'Deportes', 217.81, 1, 'Proveedor2', '2023-10-23', 'Almacén C')
# (112, 'Producto112', 'Electrónica', 394.07, 75, 'Proveedor3', '2023-12-13', 'Almacén A')
# (113, 'Objeto113', 'Hogar', 452.74, 32, 'Proveedor2', '2023-06-26', 'Almacén A')
# (114, 'Artículo114', 'Jardín', 463.23, 23, 'Proveedor1', '2023-02-01', 'Almacén A')
# (115, 'Objeto115', 'Electrónica', 200.32, 88, 'Proveedor1', '2023-03-19', 'Almacén C')
# (116, 'Artículo116', 'Electrónica', 307.43, 44, 'Proveedor1', '2023-06-23', 'Almacén B')
# (117, 'Producto117', 'Deportes', 489.43, 85, 'Proveedor1', '2023-10-19', 'Almacén A')
# (118, 'Artículo118', 'Electrónica', 233.04, 9, 'Proveedor2', '2023-11-21', 'Almacén A')
# (119, 'Producto119', 'Jardín', 430.36, 63, 'Proveedor1', '2023-12-07', 'Almacén B')
# (120, 'Producto120', 'Deportes', 254.85, 47, 'Proveedor2', '2023-06-06', 'Almacén B')
# (121, 'Objeto121', 'Moda', 399.38, 78, 'Proveedor3', '2023-06-26', 'Almacén B')
# (122, 'Producto122', 'Electrónica', 95.56, 18, 'Proveedor3', '2023-09-17', 'Almacén A')
# (123, 'Objeto123', 'Jardín', 75.43, 85, 'Proveedor2', '2023-10-18', 'Almacén A')
# (124, 'Objeto124', 'Electrónica', 344.02, 49, 'Proveedor3', '2023-01-16', 'Almacén B')
# (125, 'Producto125', 'Electrónica', 66.53, 18, 'Proveedor2', '2023-11-18', 'Almacén B')
# (126, 'Artículo126', 'Moda', 374.21, 64, 'Proveedor2', '2023-09-07', 'Almacén B')
# (127, 'Objeto127', 'Electrónica', 333.25, 5, 'Proveedor3', '2023-01-07', 'Almacén C')
# (128, 'Producto128', 'Deportes', 231.93, 87, 'Proveedor1', '2023-01-28', 'Almacén B')
# (129, 'Artículo129', 'Deportes', 289.08, 98, 'Proveedor1', '2023-08-21', 'Almacén A')
# (130, 'Objeto130', 'Electrónica', 90.51, 23, 'Proveedor3', '2023-06-12', 'Almacén B')
# (131, 'Producto131', 'Jardín', 62.39, 91, 'Proveedor2', '2023-12-23', 'Almacén B')
# (132, 'Objeto132', 'Moda', 283.97, 77, 'Proveedor3', '2023-11-17', 'Almacén C')
# (133, 'Producto133', 'Jardín', 314.79, 89, 'Proveedor1', '2023-02-26', 'Almacén C')
# (134, 'Artículo134', 'Moda', 246.32, 86, 'Proveedor2', '2023-11-13', 'Almacén B')
# (135, 'Producto135', 'Hogar', 59.32, 36, 'Proveedor2', '2023-06-23', 'Almacén A')
# (136, 'Producto136', 'Hogar', 153.39, 100, 'Proveedor3', '2023-10-11', 'Almacén B')
# (137, 'Producto137', 'Moda', 333.2, 6, 'Proveedor3', '2023-04-18', 'Almacén C')
# (138, 'Producto138', 'Deportes', 101.17, 9, 'Proveedor1', '2023-05-24', 'Almacén A')
# (139, 'Producto139', 'Jardín', 251.32, 99, 'Proveedor1', '2023-09-12', 'Almacén C')
# (140, 'Objeto140', 'Electrónica', 167.22, 1, 'Proveedor2', '2023-01-19', 'Almacén A')
# (141, 'Artículo141', 'Jardín', 474.88, 19, 'Proveedor1', '2023-06-07', 'Almacén B')
# (142, 'Artículo142', 'Hogar', 18.59, 82, 'Proveedor1', '2023-05-12', 'Almacén C')
# (143, 'Objeto143', 'Electrónica', 385.68, 10, 'Proveedor3', '2023-04-17', 'Almacén A')
# (144, 'Artículo144', 'Hogar', 421.42, 9, 'Proveedor3', '2023-07-09', 'Almacén A')
# (145, 'Objeto145', 'Jardín', 268.32, 89, 'Proveedor1', '2023-01-19', 'Almacén A')
# (146, 'Objeto146', 'Electrónica', 437.36, 3, 'Proveedor2', '2023-04-25', 'Almacén A')
# (147, 'Artículo147', 'Electrónica', 394.1, 11, 'Proveedor2', '2023-03-07', 'Almacén C')
# (148, 'Artículo148', 'Hogar', 207.37, 42, 'Proveedor1', '2023-10-14', 'Almacén B')
# (149, 'Objeto149', 'Jardín', 308.67, 30, 'Proveedor2', '2023-11-10', 'Almacén B')
# (150, 'Objeto150', 'Deportes', 294.87, 15, 'Proveedor2', '2023-09-02', 'Almacén B')
# (151, 'Producto151', 'Deportes', 318.11, 26, 'Proveedor2', '2023-11-16', 'Almacén A')
# (152, 'Objeto152', 'Jardín', 25.06, 1, 'Proveedor2', '2023-02-26', 'Almacén B')
# (153, 'Producto153', 'Jardín', 145.39, 26, 'Proveedor3', '2023-06-25', 'Almacén A')
# (154, 'Objeto154', 'Jardín', 396.75, 15, 'Proveedor2', '2023-05-03', 'Almacén B')
# (155, 'Artículo155', 'Electrónica', 75.92, 98, 'Proveedor1', '2023-11-01', 'Almacén B')
# (156, 'Producto156', 'Electrónica', 387.33, 98, 'Proveedor1', '2023-09-14', 'Almacén C')
# (157, 'Objeto157', 'Jardín', 140.52, 38, 'Proveedor3', '2023-07-03', 'Almacén C')
# (158, 'Artículo158', 'Moda', 383.6, 92, 'Proveedor1', '2023-11-14', 'Almacén C')
# (159, 'Producto159', 'Hogar', 200.85, 49, 'Proveedor2', '2023-02-14', 'Almacén B')
# (160, 'Objeto160', 'Hogar', 483.99, 59, 'Proveedor1', '2023-02-17', 'Almacén A')
# (161, 'Producto161', 'Jardín', 346.07, 59, 'Proveedor3', '2023-06-27', 'Almacén A')
# (162, 'Artículo162', 'Jardín', 261.89, 36, 'Proveedor3', '2023-11-19', 'Almacén B')
# (163, 'Producto163', 'Hogar', 319.41, 33, 'Proveedor2', '2023-11-01', 'Almacén C')
# (164, 'Producto164', 'Deportes', 376.63, 91, 'Proveedor1', '2023-01-10', 'Almacén B')
# (165, 'Objeto165', 'Hogar', 13.97, 91, 'Proveedor3', '2023-08-10', 'Almacén A')
# (166, 'Producto166', 'Jardín', 445.3, 3, 'Proveedor2', '2023-06-04', 'Almacén C')
# (167, 'Objeto167', 'Electrónica', 474.47, 91, 'Proveedor2', '2023-11-19', 'Almacén C')
# (168, 'Artículo168', 'Electrónica', 214.96, 17, 'Proveedor3', '2023-05-22', 'Almacén C')
# (169, 'Objeto169', 'Deportes', 223.49, 61, 'Proveedor3', '2023-06-06', 'Almacén A')
# (170, 'Objeto170', 'Moda', 253.92, 19, 'Proveedor1', '2023-05-04', 'Almacén C')
# (171, 'Artículo171', 'Electrónica', 324.07, 61, 'Proveedor2', '2023-12-17', 'Almacén A')
# (172, 'Producto172', 'Deportes', 204.19, 1, 'Proveedor1', '2023-03-09', 'Almacén A')
# (173, 'Artículo173', 'Electrónica', 147.04, 42, 'Proveedor3', '2023-12-22', 'Almacén C')
# (174, 'Producto174', 'Electrónica', 152.1, 26, 'Proveedor1', '2023-08-04', 'Almacén A')
# (175, 'Producto175', 'Moda', 496.7, 63, 'Proveedor1', '2023-03-05', 'Almacén C')
# (176, 'Producto176', 'Moda', 477.13, 1, 'Proveedor2', '2023-07-01', 'Almacén B')
# (177, 'Objeto177', 'Moda', 417.65, 14, 'Proveedor2', '2023-06-05', 'Almacén B')
# (178, 'Objeto178', 'Deportes', 38.16, 53, 'Proveedor3', '2023-06-24', 'Almacén C')
# (179, 'Objeto179', 'Jardín', 216.77, 5, 'Proveedor2', '2023-08-08', 'Almacén B')
# (180, 'Objeto180', 'Deportes', 237.37, 15, 'Proveedor2', '2023-07-21', 'Almacén C')
# (181, 'Objeto181', 'Moda', 295.44, 74, 'Proveedor1', '2023-08-22', 'Almacén C')
# (182, 'Objeto182', 'Hogar', 185.59, 34, 'Proveedor2', '2023-02-18', 'Almacén B')
# (183, 'Producto183', 'Electrónica', 476.45, 83, 'Proveedor3', '2023-11-28', 'Almacén A')
# (184, 'Artículo184', 'Hogar', 406.82, 73, 'Proveedor1', '2023-04-09', 'Almacén B')
# (185, 'Artículo185', 'Jardín', 138.18, 88, 'Proveedor1', '2023-12-07', 'Almacén C')
# (186, 'Objeto186', 'Electrónica', 326.87, 59, 'Proveedor1', '2023-08-16', 'Almacén A')
# (187, 'Producto187', 'Hogar', 190.38, 40, 'Proveedor3', '2023-09-12', 'Almacén C')
# (188, 'Producto188', 'Hogar', 186.16, 22, 'Proveedor3', '2023-06-03', 'Almacén A')
# (189, 'Objeto189', 'Electrónica', 162.51, 12, 'Proveedor1', '2023-05-11', 'Almacén C')
# (190, 'Artículo190', 'Moda', 159.05, 19, 'Proveedor3', '2023-08-05', 'Almacén A')
# (191, 'Artículo191', 'Moda', 227.63, 29, 'Proveedor1', '2023-06-05', 'Almacén A')
# (192, 'Producto192', 'Deportes', 148.81, 85, 'Proveedor1', '2023-04-24', 'Almacén B')
# (193, 'Objeto193', 'Deportes', 377.4, 45, 'Proveedor1', '2023-12-10', 'Almacén A')
# (194, 'Producto194', 'Hogar', 218.31, 78, 'Proveedor2', '2023-09-03', 'Almacén A')
# (195, 'Artículo195', 'Electrónica', 31.62, 86, 'Proveedor1', '2023-02-08', 'Almacén C')
# (196, 'Artículo196', 'Jardín', 184.66, 25, 'Proveedor1', '2023-08-28', 'Almacén C')
# (197, 'Artículo197', 'Hogar', 289.7, 14, 'Proveedor3', '2023-04-27', 'Almacén A')
# (198, 'Artículo198', 'Electrónica', 455.77, 25, 'Proveedor3', '2023-08-07', 'Almacén C')
# (199, 'Objeto199', 'Moda', 364.89, 84, 'Proveedor1', '2023-08-17', 'Almacén B')
# (200, 'Artículo200', 'Moda', 310.62, 44, 'Proveedor1', '2023-09-23', 'Almacén B')
# (201, 'Artículo201', 'Jardín', 367.98, 20, 'Proveedor2', '2023-04-08', 'Almacén B')
# (202, 'Artículo202', 'Deportes', 418.98, 19, 'Proveedor3', '2023-06-08', 'Almacén C')
# (203, 'Objeto203', 'Moda', 295.39, 34, 'Proveedor2', '2023-12-10', 'Almacén A')
# (204, 'Producto204', 'Hogar', 336.28, 64, 'Proveedor3', '2023-06-06', 'Almacén A')
# (205, 'Artículo205', 'Deportes', 492.33, 58, 'Proveedor1', '2023-02-03', 'Almacén C')
# (206, 'Artículo206', 'Hogar', 156.53, 21, 'Proveedor2', '2023-06-06', 'Almacén A')
# (207, 'Producto207', 'Moda', 347.59, 89, 'Proveedor1', '2023-07-11', 'Almacén A')
# (208, 'Objeto208', 'Hogar', 73.74, 24, 'Proveedor3', '2023-04-15', 'Almacén A')
# (209, 'Objeto209', 'Deportes', 238.79, 28, 'Proveedor2', '2023-04-21', 'Almacén B')
# (210, 'Producto210', 'Hogar', 49.51, 95, 'Proveedor2', '2023-12-02', 'Almacén C')
# (211, 'Artículo211', 'Hogar', 410.04, 44, 'Proveedor1', '2023-12-16', 'Almacén C')
# (212, 'Producto212', 'Hogar', 121.86, 3, 'Proveedor2', '2023-09-23', 'Almacén B')
# (213, 'Producto213', 'Electrónica', 448.73, 55, 'Proveedor3', '2023-05-26', 'Almacén B')
# (214, 'Artículo214', 'Electrónica', 231.83, 49, 'Proveedor3', '2023-03-18', 'Almacén C')
# (215, 'Objeto215', 'Hogar', 232.78, 12, 'Proveedor3', '2023-08-10', 'Almacén C')
# (216, 'Artículo216', 'Jardín', 347.46, 68, 'Proveedor2', '2023-02-17', 'Almacén C')
# (217, 'Producto217', 'Electrónica', 287.29, 45, 'Proveedor1', '2023-05-27', 'Almacén B')
# (218, 'Artículo218', 'Moda', 345.76, 70, 'Proveedor1', '2023-06-15', 'Almacén A')
# (219, 'Objeto219', 'Jardín', 471.46, 43, 'Proveedor3', '2023-02-04', 'Almacén C')
# (220, 'Producto220', 'Jardín', 352.97, 89, 'Proveedor2', '2023-03-25', 'Almacén B')
# (221, 'Artículo221', 'Electrónica', 130.12, 45, 'Proveedor1', '2023-04-20', 'Almacén C')
# (222, 'Objeto222', 'Electrónica', 198.69, 62, 'Proveedor2', '2023-08-21', 'Almacén B')
# (223, 'Objeto223', 'Jardín', 442.09, 59, 'Proveedor1', '2023-09-01', 'Almacén A')
# (224, 'Objeto224', 'Jardín', 218.47, 21, 'Proveedor1', '2023-02-15', 'Almacén B')
# (225, 'Producto225', 'Jardín', 422.84, 42, 'Proveedor1', '2023-01-11', 'Almacén B')
# (226, 'Objeto226', 'Hogar', 410.6, 20, 'Proveedor1', '2023-11-20', 'Almacén C')
# (227, 'Objeto227', 'Jardín', 148.03, 92, 'Proveedor3', '2023-02-13', 'Almacén C')
# (228, 'Producto228', 'Electrónica', 39.75, 22, 'Proveedor2', '2023-02-23', 'Almacén B')
# (229, 'Artículo229', 'Moda', 43.78, 13, 'Proveedor2', '2023-07-08', 'Almacén B')
# (230, 'Artículo230', 'Jardín', 32.58, 90, 'Proveedor3', '2023-11-04', 'Almacén C')
# (231, 'Producto231', 'Deportes', 447.46, 22, 'Proveedor1', '2023-09-18', 'Almacén A')
# (232, 'Objeto232', 'Jardín', 430.77, 25, 'Proveedor2', '2023-12-23', 'Almacén B')
# (233, 'Artículo233', 'Electrónica', 304.21, 29, 'Proveedor2', '2023-02-20', 'Almacén A')
# (234, 'Artículo234', 'Moda', 462.61, 55, 'Proveedor1', '2023-04-20', 'Almacén A')
# (235, 'Objeto235', 'Jardín', 491.06, 31, 'Proveedor1', '2023-09-08', 'Almacén C')
# (236, 'Objeto236', 'Electrónica', 320.97, 7, 'Proveedor3', '2023-04-12', 'Almacén C')
# (237, 'Producto237', 'Hogar', 138.66, 52, 'Proveedor2', '2023-09-27', 'Almacén A')
# (238, 'Artículo238', 'Hogar', 329.06, 89, 'Proveedor3', '2023-02-08', 'Almacén B')
# (239, 'Artículo239', 'Deportes', 472.49, 41, 'Proveedor2', '2023-05-13', 'Almacén B')
# (240, 'Objeto240', 'Hogar', 276.43, 10, 'Proveedor3', '2023-06-13', 'Almacén C')
# (241, 'Producto241', 'Electrónica', 298.39, 12, 'Proveedor2', '2023-02-09', 'Almacén B')
# (242, 'Artículo242', 'Hogar', 124.33, 47, 'Proveedor1', '2023-08-07', 'Almacén B')
# (243, 'Producto243', 'Hogar', 463.9, 24, 'Proveedor3', '2023-05-19', 'Almacén B')
# (244, 'Objeto244', 'Hogar', 468.07, 18, 'Proveedor3', '2023-03-05', 'Almacén C')
# (245, 'Objeto245', 'Electrónica', 249.8, 51, 'Proveedor1', '2023-09-08', 'Almacén B')
# (246, 'Artículo246', 'Moda', 332.87, 84, 'Proveedor3', '2023-12-14', 'Almacén A')
# (247, 'Producto247', 'Deportes', 145.67, 75, 'Proveedor1', '2023-09-06', 'Almacén B')
# (248, 'Objeto248', 'Hogar', 18.26, 35, 'Proveedor3', '2023-08-18', 'Almacén C')
# (249, 'Artículo249', 'Deportes', 411.01, 29, 'Proveedor3', '2023-04-18', 'Almacén A')
# (250, 'Objeto250', 'Hogar', 80.18, 83, 'Proveedor2', '2023-01-08', 'Almacén A')
# (251, 'Artículo251', 'Jardín', 109.06, 53, 'Proveedor2', '2023-07-26', 'Almacén C')
# (252, 'Objeto252', 'Hogar', 194.59, 91, 'Proveedor3', '2023-05-19', 'Almacén C')
# (253, 'Objeto253', 'Deportes', 66.41, 12, 'Proveedor1', '2023-06-08', 'Almacén A')
# (254, 'Producto254', 'Deportes', 468.55, 64, 'Proveedor3', '2023-02-16', 'Almacén C')
# (255, 'Producto255', 'Electrónica', 294.76, 36, 'Proveedor1', '2023-10-07', 'Almacén B')
# (256, 'Artículo256', 'Hogar', 160.24, 13, 'Proveedor2', '2023-09-20', 'Almacén C')
# (257, 'Artículo257', 'Jardín', 100.76, 12, 'Proveedor1', '2023-11-26', 'Almacén B')
# (258, 'Objeto258', 'Hogar', 282.33, 19, 'Proveedor2', '2023-07-14', 'Almacén A')
# (259, 'Objeto259', 'Moda', 258.89, 67, 'Proveedor2', '2023-04-12', 'Almacén C')
# (260, 'Producto260', 'Deportes', 41, 10, 'Proveedor1', '2023-01-28', 'Almacén C')
# (261, 'Objeto261', 'Electrónica', 130.02, 77, 'Proveedor3', '2023-08-24', 'Almacén B')
# (262, 'Artículo262', 'Hogar', 92.57, 60, 'Proveedor3', '2023-12-19', 'Almacén B')
# (263, 'Artículo263', 'Moda', 328.71, 36, 'Proveedor2', '2023-10-11', 'Almacén B')
# (264, 'Producto264', 'Deportes', 387.97, 61, 'Proveedor3', '2023-09-20', 'Almacén A')
# (265, 'Objeto265', 'Hogar', 237.99, 99, 'Proveedor3', '2023-08-12', 'Almacén A')
# (266, 'Objeto266', 'Hogar', 255.48, 14, 'Proveedor1', '2023-08-16', 'Almacén A')
# (267, 'Producto267', 'Deportes', 237.12, 91, 'Proveedor1', '2023-12-17', 'Almacén C')
# (268, 'Objeto268', 'Jardín', 493.09, 50, 'Proveedor1', '2023-09-08', 'Almacén A')
# (269, 'Objeto269', 'Jardín', 322.53, 64, 'Proveedor1', '2023-03-24', 'Almacén B')
# (270, 'Producto270', 'Electrónica', 266.96, 78, 'Proveedor1', '2023-03-07', 'Almacén A')
# (271, 'Producto271', 'Hogar', 303.91, 6, 'Proveedor1', '2023-04-04', 'Almacén C')
# (272, 'Artículo272', 'Jardín', 35.3, 26, 'Proveedor2', '2023-11-15', 'Almacén C')
# (273, 'Objeto273', 'Jardín', 458.5, 77, 'Proveedor2', '2023-10-16', 'Almacén B')
# (274, 'Producto274', 'Hogar', 489.53, 58, 'Proveedor2', '2023-10-17', 'Almacén A')
# (275, 'Objeto275', 'Electrónica', 314.33, 16, 'Proveedor1', '2023-06-15', 'Almacén A')
# (276, 'Artículo276', 'Moda', 284.89, 92, 'Proveedor1', '2023-10-16', 'Almacén B')
# (277, 'Artículo277', 'Jardín', 168.01, 96, 'Proveedor1', '2023-09-21', 'Almacén B')
# (278, 'Objeto278', 'Electrónica', 37.31, 19, 'Proveedor3', '2023-04-11', 'Almacén C')
# (279, 'Producto279', 'Jardín', 332.8, 51, 'Proveedor1', '2023-08-02', 'Almacén B')
# (280, 'Objeto280', 'Deportes', 341.35, 71, 'Proveedor1', '2023-07-06', 'Almacén A')
# (281, 'Objeto281', 'Electrónica', 231.29, 8, 'Proveedor2', '2023-03-11', 'Almacén C')
# (282, 'Producto282', 'Deportes', 482.31, 75, 'Proveedor2', '2023-01-22', 'Almacén C')
# (283, 'Artículo283', 'Hogar', 312.68, 88, 'Proveedor2', '2023-02-14', 'Almacén C')
# (284, 'Artículo284', 'Moda', 281.01, 84, 'Proveedor3', '2023-07-17', 'Almacén A')
# (285, 'Objeto285', 'Jardín', 214.18, 71, 'Proveedor1', '2023-07-23', 'Almacén A')
# (286, 'Artículo286', 'Jardín', 222.35, 90, 'Proveedor2', '2023-03-27', 'Almacén B')
# (287, 'Artículo287', 'Jardín', 178.37, 19, 'Proveedor3', '2023-11-22', 'Almacén C')
# (288, 'Producto288', 'Electrónica', 323.2, 81, 'Proveedor2', '2023-05-09', 'Almacén B')
# (289, 'Artículo289', 'Electrónica', 164.98, 12, 'Proveedor3', '2023-08-19', 'Almacén A')
# (290, 'Artículo290', 'Hogar', 420.75, 62, 'Proveedor3', '2023-11-26', 'Almacén C')
# (291, 'Artículo291', 'Moda', 495.76, 38, 'Proveedor3', '2023-05-19', 'Almacén B')
# (292, 'Objeto292', 'Hogar', 146.21, 51, 'Proveedor2', '2023-02-10', 'Almacén B')
# (293, 'Artículo293', 'Electrónica', 272.91, 10, 'Proveedor1', '2023-05-16', 'Almacén C')
# (294, 'Artículo294', 'Jardín', 322.82, 38, 'Proveedor3', '2023-09-22', 'Almacén B')
# (295, 'Objeto295', 'Deportes', 238.8, 9, 'Proveedor2', '2023-03-23', 'Almacén C')
# (296, 'Objeto296', 'Electrónica', 297.49, 76, 'Proveedor2', '2023-01-01', 'Almacén C')
# (297, 'Producto297', 'Electrónica', 426.4, 99, 'Proveedor3', '2023-12-18', 'Almacén A')
# (298, 'Artículo298', 'Deportes', 81.36, 69, 'Proveedor2', '2023-07-25', 'Almacén A')
# (299, 'Artículo299', 'Moda', 459.48, 57, 'Proveedor1', '2023-05-08', 'Almacén B')
# (300, 'Objeto300', 'Deportes', 21.41, 65, 'Proveedor2', '2023-11-09', 'Almacén B')
# (301, 'Artículo301', 'Deportes', 41.61, 16, 'Proveedor1', '2023-04-22', 'Almacén C')
# (302, 'Artículo302', 'Electrónica', 72.97, 32, 'Proveedor3', '2023-04-04', 'Almacén B')
# (303, 'Objeto303', 'Deportes', 434.16, 59, 'Proveedor3', '2023-01-21', 'Almacén B')
# (304, 'Artículo304', 'Electrónica', 496.24, 11, 'Proveedor2', '2023-07-09', 'Almacén B')
# (305, 'Artículo305', 'Moda', 204.17, 65, 'Proveedor1', '2023-05-18', 'Almacén A')
# (306, 'Artículo306', 'Moda', 238.49, 90, 'Proveedor1', '2023-08-14', 'Almacén C')
# (307, 'Objeto307', 'Electrónica', 333.71, 24, 'Proveedor3', '2023-04-18', 'Almacén B')
# (308, 'Artículo308', 'Jardín', 342.38, 24, 'Proveedor2', '2023-01-16', 'Almacén A')
# (309, 'Artículo309', 'Hogar', 181.87, 99, 'Proveedor2', '2023-07-15', 'Almacén C')
# (310, 'Producto310', 'Jardín', 343.58, 29, 'Proveedor1', '2023-06-08', 'Almacén A')
# (311, 'Producto311', 'Electrónica', 14.03, 86, 'Proveedor1', '2023-01-11', 'Almacén B')
# (312, 'Objeto312', 'Moda', 121.06, 6, 'Proveedor1', '2023-11-12', 'Almacén C')
# (313, 'Producto313', 'Electrónica', 91.01, 60, 'Proveedor3', '2023-03-18', 'Almacén A')
# (314, 'Artículo314', 'Hogar', 240.51, 93, 'Proveedor2', '2023-11-10', 'Almacén A')
# (315, 'Objeto315', 'Moda', 98.47, 95, 'Proveedor2', '2023-06-26', 'Almacén A')
# (316, 'Artículo316', 'Jardín', 133.98, 88, 'Proveedor2', '2023-03-15', 'Almacén B')
# (317, 'Producto317', 'Moda', 89.88, 36, 'Proveedor3', '2023-11-24', 'Almacén C')
# (318, 'Artículo318', 'Deportes', 207.76, 33, 'Proveedor2', '2023-06-25', 'Almacén B')
# (319, 'Artículo319', 'Hogar', 121.41, 82, 'Proveedor1', '2023-07-10', 'Almacén A')
# (320, 'Objeto320', 'Deportes', 148.89, 23, 'Proveedor1', '2023-11-03', 'Almacén C')
# (321, 'Objeto321', 'Hogar', 176.08, 52, 'Proveedor1', '2023-04-28', 'Almacén A')
# (322, 'Producto322', 'Deportes', 235.86, 89, 'Proveedor1', '2023-07-02', 'Almacén B')
# (323, 'Producto323', 'Hogar', 282.81, 70, 'Proveedor1', '2023-01-03', 'Almacén A')
# (324, 'Objeto324', 'Electrónica', 403.27, 16, 'Proveedor1', '2023-08-04', 'Almacén A')
# (325, 'Artículo325', 'Deportes', 25.9, 9, 'Proveedor2', '2023-07-10', 'Almacén B')
# (326, 'Objeto326', 'Electrónica', 398.95, 44, 'Proveedor1', '2023-08-24', 'Almacén A')
# (327, 'Objeto327', 'Moda', 443.58, 14, 'Proveedor2', '2023-07-09', 'Almacén A')
# (328, 'Artículo328', 'Hogar', 223.16, 30, 'Proveedor3', '2023-01-14', 'Almacén C')
# (329, 'Producto329', 'Deportes', 11.75, 51, 'Proveedor2', '2023-03-05', 'Almacén A')
# (330, 'Artículo330', 'Electrónica', 181.32, 24, 'Proveedor1', '2023-07-06', 'Almacén B')
# (331, 'Objeto331', 'Moda', 325.27, 50, 'Proveedor2', '2023-02-21', 'Almacén B')
# (332, 'Artículo332', 'Moda', 415.92, 25, 'Proveedor2', '2023-02-18', 'Almacén B')
# (333, 'Objeto333', 'Moda', 436.4, 42, 'Proveedor3', '2023-05-26', 'Almacén C')
# (334, 'Artículo334', 'Deportes', 368.04, 49, 'Proveedor3', '2023-10-11', 'Almacén C')
# (335, 'Objeto335', 'Electrónica', 455.44, 17, 'Proveedor2', '2023-11-11', 'Almacén C')
# (336, 'Artículo336', 'Moda', 202.87, 36, 'Proveedor2', '2023-07-25', 'Almacén B')
# (337, 'Producto337', 'Hogar', 366.17, 4, 'Proveedor2', '2023-04-11', 'Almacén A')
# (338, 'Producto338', 'Moda', 116.56, 86, 'Proveedor2', '2023-04-03', 'Almacén C')
# (339, 'Objeto339', 'Electrónica', 239.87, 7, 'Proveedor3', '2023-02-14', 'Almacén B')
# (340, 'Producto340', 'Deportes', 182.89, 88, 'Proveedor1', '2023-07-02', 'Almacén A')
# (341, 'Objeto341', 'Electrónica', 102.53, 98, 'Proveedor1', '2023-12-06', 'Almacén A')
# (342, 'Objeto342', 'Jardín', 181.56, 88, 'Proveedor3', '2023-03-03', 'Almacén A')
# (343, 'Artículo343', 'Deportes', 331.25, 78, 'Proveedor3', '2023-04-10', 'Almacén B')
# (344, 'Producto344', 'Electrónica', 84.05, 67, 'Proveedor2', '2023-08-20', 'Almacén B')
# (345, 'Objeto345', 'Jardín', 193.22, 24, 'Proveedor1', '2023-12-20', 'Almacén B')
# (346, 'Objeto346', 'Electrónica', 295.02, 64, 'Proveedor2', '2023-07-20', 'Almacén A')
# (347, 'Artículo347', 'Jardín', 180.38, 65, 'Proveedor2', '2023-02-09', 'Almacén A')
# (348, 'Objeto348', 'Electrónica', 87.65, 91, 'Proveedor3', '2023-05-09', 'Almacén A')
# (349, 'Producto349', 'Moda', 429.24, 96, 'Proveedor3', '2023-10-11', 'Almacén B')
# (350, 'Producto350', 'Deportes', 350.66, 99, 'Proveedor3', '2023-05-22', 'Almacén C')
# (351, 'Artículo351', 'Deportes', 37.36, 100, 'Proveedor2', '2023-05-16', 'Almacén C')
# (352, 'Producto352', 'Hogar', 231.9, 74, 'Proveedor1', '2023-11-20', 'Almacén C')
# (353, 'Artículo353', 'Deportes', 385.93, 1, 'Proveedor2', '2023-10-20', 'Almacén C')
# (354, 'Objeto354', 'Moda', 100.86, 34, 'Proveedor1', '2023-08-02', 'Almacén C')
# (355, 'Artículo355', 'Jardín', 313.9, 2, 'Proveedor2', '2023-01-13', 'Almacén C')
# (356, 'Artículo356', 'Jardín', 363.45, 55, 'Proveedor1', '2023-12-19', 'Almacén B')
# (357, 'Artículo357', 'Electrónica', 12.56, 69, 'Proveedor1', '2023-09-11', 'Almacén A')
# (358, 'Producto358', 'Jardín', 38.38, 5, 'Proveedor1', '2023-07-21', 'Almacén A')
# (359, 'Artículo359', 'Electrónica', 139.42, 80, 'Proveedor1', '2023-12-24', 'Almacén C')
# (360, 'Producto360', 'Electrónica', 351.01, 40, 'Proveedor2', '2023-06-01', 'Almacén C')
# (361, 'Artículo361', 'Electrónica', 413.08, 43, 'Proveedor2', '2023-02-04', 'Almacén B')
# (362, 'Producto362', 'Deportes', 139.38, 76, 'Proveedor2', '2023-01-08', 'Almacén B')
# (363, 'Artículo363', 'Moda', 126.09, 41, 'Proveedor3', '2023-11-15', 'Almacén C')
# (364, 'Artículo364', 'Hogar', 261.12, 40, 'Proveedor1', '2023-11-19', 'Almacén A')
# (365, 'Producto365', 'Hogar', 237.22, 1, 'Proveedor1', '2023-04-15', 'Almacén B')
# (366, 'Artículo366', 'Jardín', 421.48, 47, 'Proveedor1', '2023-01-02', 'Almacén B')
# (367, 'Objeto367', 'Hogar', 273.45, 21, 'Proveedor3', '2023-05-10', 'Almacén B')
# (368, 'Producto368', 'Moda', 382.17, 71, 'Proveedor1', '2023-09-24', 'Almacén B')
# (369, 'Artículo369', 'Hogar', 224.47, 90, 'Proveedor2', '2023-11-20', 'Almacén A')
# (370, 'Producto370', 'Hogar', 444.92, 22, 'Proveedor3', '2023-06-01', 'Almacén B')
# (371, 'Producto371', 'Deportes', 360.73, 27, 'Proveedor2', '2023-09-11', 'Almacén C')
# (372, 'Artículo372', 'Hogar', 288.63, 74, 'Proveedor2', '2023-08-21', 'Almacén A')
# (373, 'Artículo373', 'Jardín', 266.62, 21, 'Proveedor1', '2023-05-20', 'Almacén B')
# (374, 'Artículo374', 'Hogar', 316.25, 51, 'Proveedor3', '2023-12-21', 'Almacén B')
# (375, 'Objeto375', 'Electrónica', 483.21, 6, 'Proveedor1', '2023-02-27', 'Almacén C')
# (376, 'Producto376', 'Deportes', 236.81, 8, 'Proveedor1', '2023-10-26', 'Almacén C')
# (377, 'Artículo377', 'Deportes', 28.75, 33, 'Proveedor2', '2023-07-13', 'Almacén A')
# (378, 'Objeto378', 'Jardín', 397.55, 30, 'Proveedor2', '2023-01-03', 'Almacén B')
# (379, 'Artículo379', 'Electrónica', 253.65, 41, 'Proveedor3', '2023-04-22', 'Almacén B')
# (380, 'Artículo380', 'Jardín', 98.2, 64, 'Proveedor3', '2023-03-25', 'Almacén B')
# (381, 'Objeto381', 'Electrónica', 318.12, 9, 'Proveedor1', '2023-06-23', 'Almacén C')
# (382, 'Artículo382', 'Hogar', 457.99, 23, 'Proveedor2', '2023-10-28', 'Almacén B')
# (383, 'Artículo383', 'Hogar', 394.76, 17, 'Proveedor1', '2023-11-13', 'Almacén A')
# (384, 'Artículo384', 'Moda', 156.25, 19, 'Proveedor1', '2023-08-18', 'Almacén A')
# (385, 'Artículo385', 'Jardín', 385.59, 16, 'Proveedor1', '2023-04-21', 'Almacén B')
# (386, 'Artículo386', 'Jardín', 398.49, 1, 'Proveedor3', '2023-07-25', 'Almacén B')
# (387, 'Producto387', 'Moda', 135.8, 9, 'Proveedor1', '2023-12-15', 'Almacén B')
# (388, 'Producto388', 'Electrónica', 83.33, 88, 'Proveedor1', '2023-11-19', 'Almacén B')
# (389, 'Producto389', 'Deportes', 35, 87, 'Proveedor1', '2023-10-26', 'Almacén C')
# (390, 'Artículo390', 'Hogar', 484.5, 72, 'Proveedor2', '2023-06-19', 'Almacén C')
# (391, 'Artículo391', 'Jardín', 234.22, 3, 'Proveedor2', '2023-01-19', 'Almacén A')
# (392, 'Objeto392', 'Deportes', 386.31, 71, 'Proveedor1', '2023-10-27', 'Almacén A')
# (393, 'Objeto393', 'Hogar', 357.19, 28, 'Proveedor3', '2023-02-16', 'Almacén A')
# (394, 'Objeto394', 'Hogar', 341.57, 87, 'Proveedor3', '2023-05-13', 'Almacén B')
# (395, 'Producto395', 'Hogar', 312.45, 82, 'Proveedor1', '2023-02-13', 'Almacén B')
# (396, 'Objeto396', 'Electrónica', 239.61, 20, 'Proveedor3', '2023-01-04', 'Almacén A')
# (397, 'Objeto397', 'Moda', 227.54, 55, 'Proveedor3', '2023-07-22', 'Almacén B')
# (398, 'Objeto398', 'Jardín', 128.6, 8, 'Proveedor3', '2023-08-28', 'Almacén B')
# (399, 'Artículo399', 'Electrónica', 286.11, 79, 'Proveedor1', '2023-07-05', 'Almacén B')
# (400, 'Producto400', 'Hogar', 413.6, 56, 'Proveedor1', '2023-05-01', 'Almacén B')
# (401, 'Producto401', 'Moda', 449.52, 66, 'Proveedor2', '2023-04-12', 'Almacén C')
# (402, 'Producto402', 'Deportes', 46.75, 4, 'Proveedor1', '2023-02-13', 'Almacén A')
# (403, 'Objeto403', 'Moda', 424.16, 15, 'Proveedor3', '2023-07-01', 'Almacén A')
# (404, 'Objeto404', 'Moda', 86.87, 88, 'Proveedor1', '2023-02-22', 'Almacén C')
# (405, 'Artículo405', 'Electrónica', 234.98, 84, 'Proveedor1', '2023-09-22', 'Almacén C')
# (406, 'Producto406', 'Deportes', 56.1, 53, 'Proveedor3', '2023-07-10', 'Almacén B')
# (407, 'Artículo407', 'Hogar', 91.92, 13, 'Proveedor3', '2023-09-23', 'Almacén B')
# (408, 'Producto408', 'Hogar', 409.47, 73, 'Proveedor1', '2023-03-07', 'Almacén C')
# (409, 'Artículo409', 'Jardín', 60.3, 26, 'Proveedor1', '2023-10-26', 'Almacén A')
# (410, 'Objeto410', 'Deportes', 33.65, 17, 'Proveedor2', '2023-07-18', 'Almacén C')
# (411, 'Objeto411', 'Electrónica', 45.67, 17, 'Proveedor1', '2023-06-01', 'Almacén C')
# (412, 'Producto412', 'Deportes', 382.61, 67, 'Proveedor1', '2023-07-09', 'Almacén B')
# (413, 'Artículo413', 'Electrónica', 80.89, 72, 'Proveedor1', '2023-10-13', 'Almacén B')
# (414, 'Producto414', 'Moda', 83.72, 76, 'Proveedor3', '2023-03-13', 'Almacén A')
# (415, 'Objeto415', 'Jardín', 315.81, 8, 'Proveedor3', '2023-12-18', 'Almacén A')
# (416, 'Artículo416', 'Moda', 304.67, 4, 'Proveedor1', '2023-08-13', 'Almacén C')
# (417, 'Artículo417', 'Moda', 436.1, 56, 'Proveedor2', '2023-10-03', 'Almacén C')
# (418, 'Artículo418', 'Hogar', 162.44, 34, 'Proveedor1', '2023-02-23', 'Almacén A')
# (419, 'Producto419', 'Electrónica', 321.73, 96, 'Proveedor1', '2023-08-21', 'Almacén A')
# (420, 'Objeto420', 'Deportes', 157.65, 69, 'Proveedor2', '2023-11-18', 'Almacén A')
# (421, 'Objeto421', 'Deportes', 280.39, 84, 'Proveedor3', '2023-03-08', 'Almacén C')
# (422, 'Producto422', 'Hogar', 414.59, 29, 'Proveedor2', '2023-10-20', 'Almacén C')
# (423, 'Objeto423', 'Hogar', 347.93, 70, 'Proveedor1', '2023-02-09', 'Almacén A')
# (424, 'Objeto424', 'Hogar', 262.64, 18, 'Proveedor2', '2023-07-18', 'Almacén A')
# (425, 'Objeto425', 'Hogar', 192.57, 6, 'Proveedor1', '2023-03-07', 'Almacén A')
# (426, 'Artículo426', 'Electrónica', 18.68, 93, 'Proveedor3', '2023-02-24', 'Almacén A')
# (427, 'Artículo427', 'Jardín', 190.22, 51, 'Proveedor1', '2023-12-10', 'Almacén B')
# (428, 'Artículo428', 'Hogar', 38.88, 77, 'Proveedor2', '2023-11-16', 'Almacén B')
# (429, 'Objeto429', 'Jardín', 75.34, 93, 'Proveedor2', '2023-09-21', 'Almacén B')
# (430, 'Objeto430', 'Hogar', 409.64, 89, 'Proveedor3', '2023-07-12', 'Almacén B')
# (431, 'Producto431', 'Electrónica', 148.12, 75, 'Proveedor3', '2023-05-21', 'Almacén A')
# (432, 'Producto432', 'Moda', 179, 90, 'Proveedor1', '2023-04-20', 'Almacén B')
# (433, 'Producto433', 'Hogar', 111.6, 3, 'Proveedor2', '2023-10-16', 'Almacén C')
# (434, 'Artículo434', 'Jardín', 81.81, 69, 'Proveedor3', '2023-04-26', 'Almacén A')
# (435, 'Objeto435', 'Hogar', 181.69, 48, 'Proveedor2', '2023-09-18', 'Almacén C')
# (436, 'Artículo436', 'Electrónica', 329.37, 6, 'Proveedor3', '2023-09-27', 'Almacén A')
# (437, 'Producto437', 'Electrónica', 482.89, 28, 'Proveedor2', '2023-08-05', 'Almacén C')
# (438, 'Artículo438', 'Moda', 60.89, 99, 'Proveedor2', '2023-08-28', 'Almacén A')
# (439, 'Artículo439', 'Moda', 48.36, 57, 'Proveedor3', '2023-02-14', 'Almacén C')
# (440, 'Objeto440', 'Jardín', 271.62, 9, 'Proveedor1', '2023-11-20', 'Almacén C')
# (441, 'Objeto441', 'Deportes', 308.8, 54, 'Proveedor3', '2023-06-23', 'Almacén B')
# (442, 'Objeto442', 'Electrónica', 381.8, 81, 'Proveedor3', '2023-03-06', 'Almacén A')
# (443, 'Producto443', 'Hogar', 297.58, 21, 'Proveedor1', '2023-10-26', 'Almacén B')
# (444, 'Objeto444', 'Deportes', 224.02, 52, 'Proveedor3', '2023-01-21', 'Almacén C')
# (445, 'Artículo445', 'Deportes', 128.26, 9, 'Proveedor2', '2023-06-21', 'Almacén C')
# (446, 'Artículo446', 'Deportes', 105.35, 18, 'Proveedor2', '2023-07-09', 'Almacén A')
# (447, 'Producto447', 'Hogar', 352.92, 17, 'Proveedor1', '2023-03-14', 'Almacén B')
# (448, 'Producto448', 'Moda', 412.59, 33, 'Proveedor3', '2023-12-07', 'Almacén B')
# (449, 'Producto449', 'Jardín', 125.53, 71, 'Proveedor3', '2023-01-12', 'Almacén B')
# (450, 'Artículo450', 'Deportes', 411.97, 42, 'Proveedor1', '2023-12-04', 'Almacén C')
# (451, 'Objeto451', 'Moda', 268.22, 24, 'Proveedor1', '2023-03-10', 'Almacén B')
# (452, 'Producto452', 'Hogar', 164.24, 34, 'Proveedor3', '2023-11-20', 'Almacén C')
# (453, 'Artículo453', 'Deportes', 162.76, 23, 'Proveedor2', '2023-08-02', 'Almacén B')
# (454, 'Objeto454', 'Moda', 462.39, 11, 'Proveedor3', '2023-09-27', 'Almacén B')
# (455, 'Producto455', 'Deportes', 415.37, 35, 'Proveedor1', '2023-09-23', 'Almacén A')
# (456, 'Artículo456', 'Moda', 340.56, 73, 'Proveedor3', '2023-08-09', 'Almacén A')
# (457, 'Producto457', 'Jardín', 41.68, 11, 'Proveedor2', '2023-06-15', 'Almacén C')
# (458, 'Objeto458', 'Hogar', 310.4, 63, 'Proveedor2', '2023-11-11', 'Almacén C')
# (459, 'Artículo459', 'Moda', 362.56, 84, 'Proveedor3', '2023-06-27', 'Almacén A')
# (460, 'Producto460', 'Deportes', 145.04, 78, 'Proveedor2', '2023-03-26', 'Almacén C')
# (461, 'Objeto461', 'Electrónica', 18.59, 62, 'Proveedor3', '2023-05-24', 'Almacén A')
# (462, 'Artículo462', 'Moda', 497.13, 74, 'Proveedor2', '2023-05-28', 'Almacén C')
# (463, 'Objeto463', 'Hogar', 54.93, 40, 'Proveedor1', '2023-07-25', 'Almacén B')
# (464, 'Producto464', 'Jardín', 94.87, 78, 'Proveedor1', '2023-05-15', 'Almacén C')
# (465, 'Producto465', 'Jardín', 56.65, 86, 'Proveedor3', '2023-01-04', 'Almacén C')
# (466, 'Artículo466', 'Deportes', 61.09, 31, 'Proveedor2', '2023-03-14', 'Almacén A')
# (467, 'Objeto467', 'Moda', 217.67, 93, 'Proveedor2', '2023-06-03', 'Almacén C')
# (468, 'Objeto468', 'Jardín', 85.68, 45, 'Proveedor1', '2023-08-28', 'Almacén A')
# (469, 'Objeto469', 'Electrónica', 48.25, 80, 'Proveedor3', '2023-10-17', 'Almacén B')
# (470, 'Artículo470', 'Deportes', 317.82, 50, 'Proveedor2', '2023-10-16', 'Almacén C')
# (471, 'Artículo471', 'Deportes', 407.09, 92, 'Proveedor3', '2023-04-18', 'Almacén C')
# (472, 'Objeto472', 'Electrónica', 255.14, 51, 'Proveedor1', '2023-01-12', 'Almacén C')
# (473, 'Producto473', 'Deportes', 344.23, 42, 'Proveedor3', '2023-04-14', 'Almacén C')
# (474, 'Producto474', 'Moda', 453.15, 24, 'Proveedor3', '2023-08-14', 'Almacén B')
# (475, 'Producto475', 'Jardín', 53.41, 80, 'Proveedor3', '2023-08-01', 'Almacén A')
# (476, 'Artículo476', 'Moda', 465.77, 22, 'Proveedor3', '2023-09-02', 'Almacén A')
# (477, 'Artículo477', 'Moda', 412.3, 30, 'Proveedor2', '2023-08-18', 'Almacén C')
# (478, 'Objeto478', 'Jardín', 182.27, 34, 'Proveedor1', '2023-05-07', 'Almacén C')
# (479, 'Artículo479', 'Moda', 107.82, 23, 'Proveedor3', '2023-07-26', 'Almacén C')
# (480, 'Artículo480', 'Moda', 341.49, 53, 'Proveedor2', '2023-03-02', 'Almacén C')
# (481, 'Artículo481', 'Jardín', 459.69, 27, 'Proveedor3', '2023-06-12', 'Almacén C')
# (482, 'Objeto482', 'Deportes', 485.66, 5, 'Proveedor1', '2023-03-04', 'Almacén C')
# (483, 'Artículo483', 'Moda', 226.56, 78, 'Proveedor1', '2023-06-06', 'Almacén C')
# (484, 'Objeto484', 'Jardín', 192.01, 30, 'Proveedor3', '2023-01-06', 'Almacén B')
# (485, 'Producto485', 'Jardín', 92.96, 13, 'Proveedor1', '2023-11-18', 'Almacén B')
# (486, 'Producto486', 'Hogar', 403.6, 77, 'Proveedor1', '2023-02-18', 'Almacén C')
# (487, 'Objeto487', 'Deportes', 317.5, 50, 'Proveedor1', '2023-01-09', 'Almacén C')
# (488, 'Objeto488', 'Hogar', 89.35, 95, 'Proveedor2', '2023-04-08', 'Almacén C')
# (489, 'Artículo489', 'Hogar', 403.8, 7, 'Proveedor2', '2023-01-05', 'Almacén C')
# (490, 'Producto490', 'Electrónica', 198.6, 75, 'Proveedor2', '2023-07-16', 'Almacén B')
# (491, 'Artículo491', 'Deportes', 106.64, 59, 'Proveedor2', '2023-12-11', 'Almacén B')
# (492, 'Artículo492', 'Electrónica', 46.77, 38, 'Proveedor1', '2023-01-17', 'Almacén B')
# (493, 'Artículo493', 'Electrónica', 32.32, 26, 'Proveedor2', '2023-03-14', 'Almacén C')
# (494, 'Objeto494', 'Jardín', 434.91, 40, 'Proveedor3', '2023-12-17', 'Almacén C')
# (495, 'Artículo495', 'Jardín', 427.16, 71, 'Proveedor3', '2023-08-14', 'Almacén C')
# (496, 'Objeto496', 'Electrónica', 58.36, 76, 'Proveedor3', '2023-01-26', 'Almacén A')
# (497, 'Objeto497', 'Jardín', 267.53, 16, 'Proveedor1', '2023-01-08', 'Almacén A')
# (498, 'Objeto498', 'Deportes', 156.43, 94, 'Proveedor2', '2023-10-14', 'Almacén C')
# (499, 'Producto499', 'Deportes', 450.1, 29, 'Proveedor2', '2023-12-01', 'Almacén B')
# (500, 'Producto500', 'Moda', 175.74, 82, 'Proveedor3', '2023-08-23', 'Almacén B')
# (501, 'Artículo501', 'Jardín', 494.22, 82, 'Proveedor1', '2023-06-27', 'Almacén A')
# (502, 'Objeto502', 'Electrónica', 230.31, 78, 'Proveedor3', '2023-07-14', 'Almacén B')
# (503, 'Producto503', 'Jardín', 371.31, 14, 'Proveedor3', '2023-01-25', 'Almacén A')
# (504, 'Producto504', 'Moda', 431.65, 17, 'Proveedor3', '2023-06-15', 'Almacén C')
# (505, 'Objeto505', 'Electrónica', 496.63, 43, 'Proveedor1', '2023-01-27', 'Almacén C')
# (506, 'Objeto506', 'Moda', 227.75, 60, 'Proveedor3', '2023-08-12', 'Almacén A')
# (507, 'Objeto507', 'Deportes', 429.45, 11, 'Proveedor1', '2023-08-28', 'Almacén A')
# (508, 'Objeto508', 'Deportes', 90.16, 53, 'Proveedor1', '2023-10-10', 'Almacén C')
# (509, 'Objeto509', 'Electrónica', 454.72, 58, 'Proveedor3', '2023-07-11', 'Almacén A')
# (510, 'Artículo510', 'Jardín', 401.42, 16, 'Proveedor1', '2023-02-24', 'Almacén A')
# (511, 'Producto511', 'Electrónica', 349.37, 27, 'Proveedor2', '2023-04-12', 'Almacén B')
# (512, 'Producto512', 'Deportes', 184.98, 59, 'Proveedor1', '2023-09-15', 'Almacén B')
# (513, 'Producto513', 'Jardín', 436.4, 40, 'Proveedor2', '2023-08-01', 'Almacén B')
# (514, 'Objeto514', 'Electrónica', 340.02, 89, 'Proveedor3', '2023-08-06', 'Almacén B')
# (515, 'Artículo515', 'Electrónica', 136.52, 95, 'Proveedor1', '2023-02-17', 'Almacén A')
# (516, 'Artículo516', 'Hogar', 264.13, 52, 'Proveedor1', '2023-05-25', 'Almacén C')
# (517, 'Producto517', 'Jardín', 236.87, 96, 'Proveedor1', '2023-06-22', 'Almacén B')
# (518, 'Producto518', 'Jardín', 419.58, 86, 'Proveedor2', '2023-11-13', 'Almacén A')
# (519, 'Objeto519', 'Hogar', 320.46, 29, 'Proveedor3', '2023-01-25', 'Almacén C')
# (520, 'Producto520', 'Deportes', 215.66, 37, 'Proveedor3', '2023-01-27', 'Almacén B')
# (521, 'Producto521', 'Electrónica', 327.76, 43, 'Proveedor2', '2023-02-23', 'Almacén A')
# (522, 'Objeto522', 'Hogar', 140.87, 59, 'Proveedor1', '2023-10-10', 'Almacén A')
# (523, 'Producto523', 'Deportes', 13.69, 99, 'Proveedor2', '2023-11-09', 'Almacén A')
# (524, 'Objeto524', 'Electrónica', 411.32, 63, 'Proveedor2', '2023-09-06', 'Almacén C')
# (525, 'Artículo525', 'Deportes', 17.46, 82, 'Proveedor3', '2023-09-16', 'Almacén C')
# (526, 'Objeto526', 'Moda', 21.79, 95, 'Proveedor1', '2023-11-26', 'Almacén B')
# (527, 'Artículo527', 'Electrónica', 134.68, 85, 'Proveedor3', '2023-10-25', 'Almacén A')
# (528, 'Artículo528', 'Electrónica', 171.32, 32, 'Proveedor3', '2023-01-20', 'Almacén A')
# (529, 'Artículo529', 'Moda', 111.92, 37, 'Proveedor2', '2023-08-27', 'Almacén B')
# (530, 'Artículo530', 'Hogar', 40.93, 43, 'Proveedor1', '2023-11-06', 'Almacén C')
# (531, 'Objeto531', 'Hogar', 341.46, 75, 'Proveedor3', '2023-01-05', 'Almacén A')
# (532, 'Producto532', 'Hogar', 412.11, 72, 'Proveedor3', '2023-09-24', 'Almacén A')
# (533, 'Artículo533', 'Electrónica', 304.43, 57, 'Proveedor3', '2023-10-18', 'Almacén A')
# (534, 'Producto534', 'Jardín', 275.27, 34, 'Proveedor2', '2023-06-01', 'Almacén A')
# (535, 'Producto535', 'Electrónica', 414.82, 80, 'Proveedor3', '2023-08-25', 'Almacén C')
# (536, 'Objeto536', 'Hogar', 69.77, 58, 'Proveedor2', '2023-04-18', 'Almacén C')
# (537, 'Objeto537', 'Jardín', 251.65, 97, 'Proveedor3', '2023-01-15', 'Almacén C')
# (538, 'Producto538', 'Hogar', 426.03, 69, 'Proveedor2', '2023-10-08', 'Almacén A')
# (539, 'Objeto539', 'Electrónica', 425.48, 82, 'Proveedor3', '2023-02-18', 'Almacén A')
# (540, 'Producto540', 'Hogar', 444.36, 21, 'Proveedor1', '2023-01-07', 'Almacén B')
# (541, 'Producto541', 'Moda', 197.95, 46, 'Proveedor1', '2023-11-12', 'Almacén C')
# (542, 'Artículo542', 'Deportes', 228.72, 27, 'Proveedor2', '2023-05-17', 'Almacén C')
# (543, 'Objeto543', 'Deportes', 458.46, 68, 'Proveedor1', '2023-12-18', 'Almacén A')
# (544, 'Producto544', 'Moda', 145.8, 71, 'Proveedor2', '2023-08-04', 'Almacén C')
# (545, 'Producto545', 'Jardín', 239.99, 53, 'Proveedor2', '2023-05-02', 'Almacén B')
# (546, 'Producto546', 'Deportes', 237.49, 65, 'Proveedor3', '2023-11-05', 'Almacén B')
# (547, 'Artículo547', 'Moda', 95.68, 94, 'Proveedor3', '2023-09-16', 'Almacén B')
# (548, 'Producto548', 'Electrónica', 446.13, 74, 'Proveedor1', '2023-02-16', 'Almacén C')
# (549, 'Producto549', 'Deportes', 54.28, 47, 'Proveedor3', '2023-07-26', 'Almacén C')
# (550, 'Artículo550', 'Jardín', 220.57, 95, 'Proveedor1', '2023-09-27', 'Almacén B')
# (551, 'Objeto551', 'Jardín', 491.18, 9, 'Proveedor1', '2023-05-24', 'Almacén B')
# (552, 'Artículo552', 'Deportes', 42.74, 20, 'Proveedor3', '2023-11-12', 'Almacén C')
# (553, 'Artículo553', 'Jardín', 194.31, 24, 'Proveedor2', '2023-01-05', 'Almacén B')
# (554, 'Producto554', 'Electrónica', 63.61, 88, 'Proveedor2', '2023-01-20', 'Almacén A')
# (555, 'Objeto555', 'Electrónica', 203.22, 10, 'Proveedor3', '2023-01-12', 'Almacén C')
# (556, 'Producto556', 'Deportes', 236.76, 32, 'Proveedor1', '2023-05-22', 'Almacén A')
# (557, 'Artículo557', 'Moda', 340.41, 84, 'Proveedor1', '2023-11-14', 'Almacén C')
# (558, 'Producto558', 'Deportes', 353.56, 12, 'Proveedor2', '2023-08-27', 'Almacén A')
# (559, 'Objeto559', 'Moda', 171.83, 64, 'Proveedor1', '2023-04-10', 'Almacén A')
# (560, 'Producto560', 'Hogar', 324.84, 84, 'Proveedor1', '2023-12-19', 'Almacén A')
# (561, 'Artículo561', 'Hogar', 308.43, 78, 'Proveedor3', '2023-09-19', 'Almacén B')
# (562, 'Artículo562', 'Hogar', 58.47, 27, 'Proveedor3', '2023-07-13', 'Almacén C')
# (563, 'Objeto563', 'Electrónica', 292.65, 3, 'Proveedor1', '2023-06-11', 'Almacén A')
# (564, 'Objeto564', 'Jardín', 434.43, 10, 'Proveedor1', '2023-01-13', 'Almacén B')
# (565, 'Objeto565', 'Jardín', 202.43, 43, 'Proveedor3', '2023-07-08', 'Almacén C')
# (566, 'Objeto566', 'Electrónica', 23.96, 90, 'Proveedor2', '2023-01-11', 'Almacén A')
# (567, 'Producto567', 'Electrónica', 127.72, 22, 'Proveedor2', '2023-12-06', 'Almacén A')
# (568, 'Artículo568', 'Moda', 387.89, 42, 'Proveedor2', '2023-08-18', 'Almacén A')
# (569, 'Producto569', 'Moda', 389.01, 14, 'Proveedor3', '2023-07-25', 'Almacén B')
# (570, 'Objeto570', 'Moda', 402.97, 69, 'Proveedor1', '2023-01-26', 'Almacén C')
# (571, 'Objeto571', 'Jardín', 496.76, 63, 'Proveedor3', '2023-09-15', 'Almacén C')
# (572, 'Producto572', 'Jardín', 439.53, 66, 'Proveedor1', '2023-09-16', 'Almacén A')
# (573, 'Artículo573', 'Deportes', 351.4, 10, 'Proveedor1', '2023-11-11', 'Almacén C')
# (574, 'Artículo574', 'Deportes', 402.19, 95, 'Proveedor3', '2023-04-02', 'Almacén C')
# ...
# (24817, 'Artículo9816', 'Deportes', 495.44, 62, 'Proveedor2', '2023-03-08', 'Almacén C')
# (24818, 'Objeto9817', 'Jardín', 295.22, 77, 'Proveedor3', '2023-11-01', 'Almacén B')
# (24819, 'Objeto9818', 'Deportes', 268.45, 86, 'Proveedor1', '2023-04-22', 'Almacén A')
# (24820, 'Artículo9819', 'Jardín', 417.19, 82, 'Proveedor1', '2023-04-10', 'Almacén A')
# (24821, 'Objeto9820', 'Electrónica', 136.12, 74, 'Proveedor2', '2023-05-05', 'Almacén B')
# (24822, 'Producto9821', 'Jardín', 37.77, 45, 'Proveedor2', '2023-08-21', 'Almacén C')
# (24823, 'Objeto9822', 'Jardín', 388.3, 74, 'Proveedor3', '2023-02-01', 'Almacén C')
# (24824, 'Artículo9823', 'Jardín', 73.57, 77, 'Proveedor3', '2023-02-04', 'Almacén B')
# (24825, 'Producto9824', 'Hogar', 141.63, 60, 'Proveedor3', '2023-09-21', 'Almacén B')
# (24826, 'Producto9825', 'Deportes', 295.36, 40, 'Proveedor1', '2023-10-10', 'Almacén A')
# (24827, 'Objeto9826', 'Jardín', 353.47, 50, 'Proveedor1', '2023-10-09', 'Almacén B')
# (24828, 'Artículo9827', 'Hogar', 104, 30, 'Proveedor1', '2023-08-17', 'Almacén C')
# (24829, 'Objeto9828', 'Deportes', 202.35, 75, 'Proveedor1', '2023-06-15', 'Almacén C')
# (24830, 'Artículo9829', 'Deportes', 240.99, 54, 'Proveedor2', '2023-02-03', 'Almacén B')
# (24831, 'Objeto9830', 'Jardín', 37.21, 100, 'Proveedor2', '2023-02-07', 'Almacén A')
# (24832, 'Objeto9831', 'Moda', 86.78, 96, 'Proveedor1', '2023-10-05', 'Almacén B')
# (24833, 'Objeto9832', 'Jardín', 209.81, 60, 'Proveedor2', '2023-04-01', 'Almacén B')
# (24834, 'Objeto9833', 'Hogar', 240.76, 23, 'Proveedor3', '2023-06-18', 'Almacén A')
# (24835, 'Objeto9834', 'Deportes', 195.86, 9, 'Proveedor3', '2023-10-23', 'Almacén A')
# (24836, 'Objeto9835', 'Electrónica', 153.61, 31, 'Proveedor1', '2023-07-16', 'Almacén C')
# (24837, 'Objeto9836', 'Deportes', 467.28, 17, 'Proveedor2', '2023-12-19', 'Almacén A')
# (24838, 'Objeto9837', 'Hogar', 216.72, 95, 'Proveedor3', '2023-06-11', 'Almacén C')
# (24839, 'Objeto9838', 'Moda', 196.18, 93, 'Proveedor1', '2023-09-20', 'Almacén C')
# (24840, 'Artículo9839', 'Hogar', 405.24, 94, 'Proveedor2', '2023-02-04', 'Almacén C')
# (24841, 'Objeto9840', 'Moda', 184.14, 23, 'Proveedor3', '2023-10-09', 'Almacén A')
# (24842, 'Objeto9841', 'Hogar', 417.79, 21, 'Proveedor3', '2023-08-20', 'Almacén A')
# (24843, 'Objeto9842', 'Deportes', 293.4, 22, 'Proveedor3', '2023-03-09', 'Almacén B')
# (24844, 'Objeto9843', 'Hogar', 121.76, 47, 'Proveedor3', '2023-06-02', 'Almacén B')
# (24845, 'Objeto9844', 'Moda', 50.82, 57, 'Proveedor3', '2023-12-18', 'Almacén A')
# (24846, 'Artículo9845', 'Jardín', 483.67, 95, 'Proveedor1', '2023-09-22', 'Almacén B')
# (24847, 'Objeto9846', 'Electrónica', 336.88, 3, 'Proveedor2', '2023-02-27', 'Almacén B')
# (24848, 'Artículo9847', 'Moda', 205.18, 25, 'Proveedor1', '2023-11-21', 'Almacén C')
# (24849, 'Artículo9848', 'Electrónica', 276.07, 70, 'Proveedor2', '2023-03-16', 'Almacén C')
# (24850, 'Producto9849', 'Deportes', 207, 95, 'Proveedor1', '2023-08-04', 'Almacén B')
# (24851, 'Objeto9850', 'Jardín', 138.61, 78, 'Proveedor2', '2023-04-19', 'Almacén B')
# (24852, 'Artículo9851', 'Hogar', 372.16, 70, 'Proveedor1', '2023-06-03', 'Almacén A')
# (24853, 'Artículo9852', 'Electrónica', 450.61, 62, 'Proveedor2', '2023-01-10', 'Almacén B')
# (24854, 'Objeto9853', 'Hogar', 257.14, 11, 'Proveedor3', '2023-05-08', 'Almacén C')
# (24855, 'Artículo9854', 'Jardín', 306.61, 93, 'Proveedor2', '2023-12-16', 'Almacén C')
# (24856, 'Objeto9855', 'Deportes', 411.57, 21, 'Proveedor2', '2023-03-11', 'Almacén B')
# (24857, 'Objeto9856', 'Moda', 188.81, 16, 'Proveedor2', '2023-03-01', 'Almacén C')
# (24858, 'Artículo9857', 'Moda', 238.83, 52, 'Proveedor3', '2023-07-19', 'Almacén A')
# (24859, 'Producto9858', 'Jardín', 316.43, 72, 'Proveedor2', '2023-06-21', 'Almacén B')
# (24860, 'Objeto9859', 'Jardín', 181.75, 58, 'Proveedor2', '2023-07-18', 'Almacén B')
# (24861, 'Objeto9860', 'Deportes', 447.91, 95, 'Proveedor1', '2023-12-17', 'Almacén B')
# (24862, 'Producto9861', 'Hogar', 21.94, 34, 'Proveedor1', '2023-05-20', 'Almacén C')
# (24863, 'Objeto9862', 'Electrónica', 190.23, 63, 'Proveedor3', '2023-12-06', 'Almacén B')
# (24864, 'Producto9863', 'Jardín', 369.71, 74, 'Proveedor2', '2023-05-04', 'Almacén C')
# (24865, 'Producto9864', 'Hogar', 49.76, 7, 'Proveedor3', '2023-02-26', 'Almacén A')
# (24866, 'Artículo9865', 'Hogar', 283.83, 31, 'Proveedor3', '2023-11-27', 'Almacén C')
# (24867, 'Artículo9866', 'Jardín', 153.16, 12, 'Proveedor3', '2023-02-13', 'Almacén C')
# (24868, 'Artículo9867', 'Hogar', 36.82, 26, 'Proveedor1', '2023-03-11', 'Almacén C')
# (24869, 'Producto9868', 'Deportes', 65.46, 27, 'Proveedor2', '2023-12-12', 'Almacén C')
# (24870, 'Artículo9869', 'Hogar', 99.54, 66, 'Proveedor1', '2023-06-17', 'Almacén A')
# (24871, 'Objeto9870', 'Hogar', 112.05, 49, 'Proveedor2', '2023-12-04', 'Almacén A')
# (24872, 'Objeto9871', 'Electrónica', 25.02, 36, 'Proveedor3', '2023-05-14', 'Almacén B')
# (24873, 'Objeto9872', 'Jardín', 94.67, 72, 'Proveedor2', '2023-01-07', 'Almacén A')
# (24874, 'Objeto9873', 'Deportes', 155.39, 35, 'Proveedor3', '2023-05-27', 'Almacén B')
# (24875, 'Objeto9874', 'Jardín', 217.64, 87, 'Proveedor2', '2023-11-03', 'Almacén A')
# (24876, 'Producto9875', 'Jardín', 369.1, 37, 'Proveedor3', '2023-01-11', 'Almacén A')
# (24877, 'Producto9876', 'Deportes', 328.98, 63, 'Proveedor2', '2023-04-23', 'Almacén B')
# (24878, 'Objeto9877', 'Hogar', 27.85, 17, 'Proveedor1', '2023-09-04', 'Almacén B')
# (24879, 'Producto9878', 'Moda', 390.89, 39, 'Proveedor2', '2023-05-06', 'Almacén B')
# (24880, 'Artículo9879', 'Deportes', 215.58, 62, 'Proveedor1', '2023-12-20', 'Almacén A')
# (24881, 'Objeto9880', 'Moda', 64.1, 42, 'Proveedor2', '2023-12-04', 'Almacén A')
# (24882, 'Artículo9881', 'Deportes', 304.6, 66, 'Proveedor1', '2023-03-26', 'Almacén A')
# (24883, 'Objeto9882', 'Moda', 39.64, 50, 'Proveedor2', '2023-03-27', 'Almacén B')
# (24884, 'Producto9883', 'Electrónica', 383.12, 84, 'Proveedor3', '2023-01-16', 'Almacén B')
# (24885, 'Objeto9884', 'Jardín', 334.26, 8, 'Proveedor3', '2023-02-12', 'Almacén C')
# (24886, 'Artículo9885', 'Moda', 436.46, 28, 'Proveedor3', '2023-06-24', 'Almacén B')
# (24887, 'Artículo9886', 'Moda', 215.95, 45, 'Proveedor3', '2023-12-15', 'Almacén A')
# (24888, 'Producto9887', 'Moda', 69, 21, 'Proveedor1', '2023-12-15', 'Almacén B')
# (24889, 'Producto9888', 'Hogar', 103.34, 62, 'Proveedor3', '2023-06-23', 'Almacén A')
# (24890, 'Objeto9889', 'Moda', 92.48, 65, 'Proveedor1', '2023-06-11', 'Almacén B')
# (24891, 'Artículo9890', 'Deportes', 412.23, 70, 'Proveedor3', '2023-12-03', 'Almacén A')
# (24892, 'Objeto9891', 'Deportes', 179.3, 33, 'Proveedor1', '2023-10-05', 'Almacén A')
# (24893, 'Objeto9892', 'Jardín', 369.24, 63, 'Proveedor1', '2023-01-01', 'Almacén B')
# (24894, 'Producto9893', 'Hogar', 188.66, 21, 'Proveedor3', '2023-06-20', 'Almacén B')
# (24895, 'Producto9894', 'Jardín', 247.37, 24, 'Proveedor1', '2023-10-03', 'Almacén C')
# (24896, 'Producto9895', 'Moda', 321.48, 87, 'Proveedor1', '2023-05-28', 'Almacén A')
# (24897, 'Artículo9896', 'Deportes', 365.61, 59, 'Proveedor3', '2023-12-14', 'Almacén C')
# (24898, 'Artículo9897', 'Jardín', 401.14, 5, 'Proveedor2', '2023-09-08', 'Almacén C')
# (24899, 'Objeto9898', 'Moda', 68.52, 38, 'Proveedor1', '2023-12-06', 'Almacén A')
# (24900, 'Artículo9899', 'Hogar', 400.17, 95, 'Proveedor1', '2023-08-26', 'Almacén A')
# (24901, 'Artículo9900', 'Moda', 426.47, 42, 'Proveedor3', '2023-01-22', 'Almacén B')
# (24902, 'Objeto9901', 'Moda', 299.3, 97, 'Proveedor2', '2023-07-27', 'Almacén C')
# (24903, 'Producto9902', 'Hogar', 143.59, 100, 'Proveedor3', '2023-06-26', 'Almacén C')
# (24904, 'Producto9903', 'Jardín', 336.1, 31, 'Proveedor3', '2023-07-10', 'Almacén A')
# (24905, 'Producto9904', 'Jardín', 310.87, 34, 'Proveedor2', '2023-01-14', 'Almacén B')
# (24906, 'Artículo9905', 'Electrónica', 39.05, 8, 'Proveedor2', '2023-08-15', 'Almacén A')
# (24907, 'Artículo9906', 'Moda', 416.51, 45, 'Proveedor3', '2023-06-04', 'Almacén C')
# (24908, 'Artículo9907', 'Moda', 25.31, 27, 'Proveedor1', '2023-05-02', 'Almacén A')
# (24909, 'Producto9908', 'Hogar', 389.14, 63, 'Proveedor1', '2023-09-14', 'Almacén B')
# (24910, 'Artículo9909', 'Deportes', 75.12, 31, 'Proveedor3', '2023-10-01', 'Almacén B')
# (24911, 'Artículo9910', 'Hogar', 175.86, 90, 'Proveedor1', '2023-04-25', 'Almacén C')
# (24912, 'Producto9911', 'Moda', 453.96, 50, 'Proveedor2', '2023-05-12', 'Almacén B')
# (24913, 'Artículo9912', 'Deportes', 369.31, 91, 'Proveedor2', '2023-12-19', 'Almacén C')
# (24914, 'Artículo9913', 'Hogar', 73.05, 14, 'Proveedor2', '2023-10-12', 'Almacén C')
# (24915, 'Producto9914', 'Deportes', 44.84, 16, 'Proveedor3', '2023-04-03', 'Almacén B')
# (24916, 'Objeto9915', 'Electrónica', 338.57, 80, 'Proveedor3', '2023-02-26', 'Almacén B')
# (24917, 'Objeto9916', 'Moda', 107.27, 72, 'Proveedor3', '2023-05-07', 'Almacén C')
# (24918, 'Artículo9917', 'Deportes', 373.54, 96, 'Proveedor1', '2023-08-11', 'Almacén A')
# (24919, 'Producto9918', 'Electrónica', 18.14, 70, 'Proveedor3', '2023-01-21', 'Almacén B')
# (24920, 'Artículo9919', 'Hogar', 385.05, 15, 'Proveedor3', '2023-02-25', 'Almacén C')
# (24921, 'Artículo9920', 'Jardín', 351.25, 7, 'Proveedor2', '2023-03-23', 'Almacén C')
# (24922, 'Objeto9921', 'Electrónica', 248.22, 96, 'Proveedor2', '2023-09-24', 'Almacén B')
# (24923, 'Objeto9922', 'Deportes', 244.67, 97, 'Proveedor2', '2023-10-10', 'Almacén B')
# (24924, 'Artículo9923', 'Jardín', 103.81, 36, 'Proveedor1', '2023-01-06', 'Almacén A')
# (24925, 'Producto9924', 'Moda', 304.59, 54, 'Proveedor1', '2023-12-07', 'Almacén C')
# (24926, 'Objeto9925', 'Hogar', 497.99, 40, 'Proveedor1', '2023-09-28', 'Almacén A')
# (24927, 'Objeto9926', 'Deportes', 110.09, 28, 'Proveedor3', '2023-10-23', 'Almacén C')
# (24928, 'Producto9927', 'Moda', 48.27, 89, 'Proveedor2', '2023-03-11', 'Almacén B')
# (24929, 'Producto9928', 'Electrónica', 152.77, 64, 'Proveedor3', '2023-01-20', 'Almacén A')
# (24930, 'Objeto9929', 'Hogar', 389.23, 88, 'Proveedor3', '2023-05-14', 'Almacén A')
# (24931, 'Artículo9930', 'Electrónica', 479, 70, 'Proveedor3', '2023-08-13', 'Almacén C')
# (24932, 'Objeto9931', 'Jardín', 158.26, 20, 'Proveedor2', '2023-10-04', 'Almacén B')
# (24933, 'Producto9932', 'Moda', 362.34, 29, 'Proveedor3', '2023-03-03', 'Almacén C')
# (24934, 'Producto9933', 'Jardín', 497.58, 84, 'Proveedor3', '2023-10-08', 'Almacén A')
# (24935, 'Objeto9934', 'Electrónica', 109.02, 56, 'Proveedor1', '2023-12-16', 'Almacén C')
# (24936, 'Producto9935', 'Electrónica', 174.1, 63, 'Proveedor2', '2023-04-05', 'Almacén C')
# (24937, 'Objeto9936', 'Hogar', 497.92, 49, 'Proveedor2', '2023-12-04', 'Almacén C')
# (24938, 'Artículo9937', 'Hogar', 194.36, 95, 'Proveedor1', '2023-02-01', 'Almacén B')
# (24939, 'Artículo9938', 'Hogar', 285.51, 2, 'Proveedor2', '2023-09-03', 'Almacén B')
# (24940, 'Objeto9939', 'Hogar', 260.47, 82, 'Proveedor1', '2023-07-10', 'Almacén C')
# (24941, 'Artículo9940', 'Hogar', 194.61, 4, 'Proveedor1', '2023-01-13', 'Almacén B')
# (24942, 'Objeto9941', 'Jardín', 217.22, 5, 'Proveedor2', '2023-08-25', 'Almacén B')
# (24943, 'Objeto9942', 'Electrónica', 337.31, 9, 'Proveedor1', '2023-06-01', 'Almacén C')
# (24944, 'Artículo9943', 'Hogar', 48.32, 94, 'Proveedor2', '2023-05-03', 'Almacén C')
# (24945, 'Objeto9944', 'Deportes', 48.32, 83, 'Proveedor2', '2023-09-02', 'Almacén C')
# (24946, 'Artículo9945', 'Electrónica', 182.5, 44, 'Proveedor1', '2023-11-12', 'Almacén B')
# (24947, 'Producto9946', 'Deportes', 286.05, 78, 'Proveedor1', '2023-06-18', 'Almacén A')
# (24948, 'Producto9947', 'Deportes', 36.51, 54, 'Proveedor2', '2023-02-18', 'Almacén A')
# (24949, 'Artículo9948', 'Electrónica', 351.06, 20, 'Proveedor1', '2023-12-15', 'Almacén B')
# (24950, 'Objeto9949', 'Moda', 116.33, 55, 'Proveedor1', '2023-10-15', 'Almacén A')
# (24951, 'Producto9950', 'Jardín', 458.4, 67, 'Proveedor1', '2023-12-20', 'Almacén A')
# (24952, 'Objeto9951', 'Moda', 375.94, 59, 'Proveedor2', '2023-08-04', 'Almacén B')
# (24953, 'Artículo9952', 'Hogar', 418.73, 20, 'Proveedor3', '2023-02-02', 'Almacén A')
# (24954, 'Objeto9953', 'Electrónica', 376.46, 74, 'Proveedor2', '2023-05-06', 'Almacén B')
# (24955, 'Producto9954', 'Deportes', 120.1, 83, 'Proveedor3', '2023-08-13', 'Almacén B')
# (24956, 'Artículo9955', 'Deportes', 446.53, 68, 'Proveedor3', '2023-07-26', 'Almacén A')
# (24957, 'Producto9956', 'Jardín', 446.32, 42, 'Proveedor3', '2023-11-02', 'Almacén A')
# (24958, 'Artículo9957', 'Deportes', 161.44, 31, 'Proveedor2', '2023-01-09', 'Almacén A')
# (24959, 'Artículo9958', 'Electrónica', 102.02, 22, 'Proveedor2', '2023-04-03', 'Almacén A')
# (24960, 'Artículo9959', 'Electrónica', 331.99, 12, 'Proveedor2', '2023-01-20', 'Almacén B')
# (24961, 'Artículo9960', 'Electrónica', 75.63, 89, 'Proveedor1', '2023-08-13', 'Almacén C')
# (24962, 'Artículo9961', 'Deportes', 421.1, 15, 'Proveedor1', '2023-08-11', 'Almacén A')
# (24963, 'Artículo9962', 'Jardín', 60.63, 92, 'Proveedor2', '2023-12-16', 'Almacén B')
# (24964, 'Artículo9963', 'Deportes', 289.65, 46, 'Proveedor1', '2023-12-03', 'Almacén B')
# (24965, 'Producto9964', 'Jardín', 125.12, 2, 'Proveedor3', '2023-09-03', 'Almacén B')
# (24966, 'Producto9965', 'Moda', 314.26, 94, 'Proveedor2', '2023-05-13', 'Almacén B')
# (24967, 'Artículo9966', 'Hogar', 345.77, 91, 'Proveedor2', '2023-11-27', 'Almacén C')
# (24968, 'Producto9967', 'Deportes', 364.49, 16, 'Proveedor1', '2023-12-23', 'Almacén A')
# (24969, 'Objeto9968', 'Moda', 167.11, 20, 'Proveedor2', '2023-09-26', 'Almacén A')
# (24970, 'Objeto9969', 'Deportes', 57.8, 32, 'Proveedor2', '2023-08-11', 'Almacén A')
# (24971, 'Objeto9970', 'Moda', 368.11, 97, 'Proveedor3', '2023-02-12', 'Almacén A')
# (24972, 'Producto9971', 'Hogar', 365.31, 53, 'Proveedor1', '2023-11-07', 'Almacén A')
# (24973, 'Producto9972', 'Jardín', 283.58, 96, 'Proveedor3', '2023-01-08', 'Almacén A')
# (24974, 'Objeto9973', 'Jardín', 330.78, 68, 'Proveedor1', '2023-09-14', 'Almacén C')
# (24975, 'Producto9974', 'Jardín', 192.97, 60, 'Proveedor3', '2023-05-07', 'Almacén A')
# (24976, 'Producto9975', 'Moda', 449.18, 31, 'Proveedor1', '2023-12-07', 'Almacén B')
# (24977, 'Objeto9976', 'Deportes', 133.3, 40, 'Proveedor3', '2023-04-06', 'Almacén B')
# (24978, 'Objeto9977', 'Jardín', 120.71, 57, 'Proveedor3', '2023-06-11', 'Almacén C')
# (24979, 'Producto9978', 'Jardín', 375.83, 22, 'Proveedor2', '2023-02-12', 'Almacén C')
# (24980, 'Producto9979', 'Deportes', 366.47, 6, 'Proveedor1', '2023-08-10', 'Almacén A')
# (24981, 'Artículo9980', 'Jardín', 426.35, 79, 'Proveedor2', '2023-07-28', 'Almacén C')
# (24982, 'Artículo9981', 'Electrónica', 172.45, 17, 'Proveedor1', '2023-11-04', 'Almacén A')
# (24983, 'Producto9982', 'Moda', 430.07, 46, 'Proveedor3', '2023-10-12', 'Almacén A')
# (24984, 'Producto9983', 'Hogar', 408.78, 14, 'Proveedor2', '2023-10-23', 'Almacén C')
# (24985, 'Objeto9984', 'Electrónica', 146.88, 33, 'Proveedor3', '2023-03-06', 'Almacén B')
# (24986, 'Producto9985', 'Hogar', 417.7, 50, 'Proveedor1', '2023-12-24', 'Almacén C')
# (24987, 'Producto9986', 'Moda', 471.04, 52, 'Proveedor3', '2023-04-20', 'Almacén C')
# (24988, 'Producto9987', 'Electrónica', 368.24, 67, 'Proveedor3', '2023-12-14', 'Almacén C')
# (24989, 'Producto9988', 'Jardín', 257.65, 40, 'Proveedor3', '2023-06-15', 'Almacén B')
# (24990, 'Artículo9989', 'Hogar', 381.65, 28, 'Proveedor3', '2023-05-19', 'Almacén A')
# (24991, 'Objeto9990', 'Moda', 211.2, 19, 'Proveedor1', '2023-01-25', 'Almacén B')
# (24992, 'Artículo9991', 'Electrónica', 94.57, 57, 'Proveedor2', '2023-07-23', 'Almacén B')
# (24993, 'Objeto9992', 'Electrónica', 317.15, 13, 'Proveedor1', '2023-05-09', 'Almacén B')
# (24994, 'Producto9993', 'Jardín', 396.75, 100, 'Proveedor2', '2023-06-13', 'Almacén B')
# (24995, 'Objeto9994', 'Moda', 118.32, 33, 'Proveedor1', '2023-04-25', 'Almacén B')
# (24996, 'Artículo9995', 'Electrónica', 28.07, 18, 'Proveedor2', '2023-08-01', 'Almacén B')
# (24997, 'Objeto9996', 'Deportes', 326.46, 69, 'Proveedor2', '2023-02-23', 'Almacén B')
# (24998, 'Objeto9997', 'Hogar', 28.64, 26, 'Proveedor2', '2023-03-15', 'Almacén B')
# (24999, 'Artículo9998', 'Moda', 304.58, 13, 'Proveedor1', '2023-08-28', 'Almacén C')
# (25000, 'Artículo9999', 'Hogar', 226.5, 33, 'Proveedor2', '2023-09-07', 'Almacén C')
# (25001, 'Objeto10000', 'Deportes', 100.58, 76, 'Proveedor2', '2023-06-06', 'Almacén B')

# %% [markdown]
# ## Realizar consulta y transferir a dataframe

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#          id        nombre    categoria  precio  cantidad   proveedor  \
# 0        12    Artículo12        Hogar  479.09        78  Proveedor3
# 1        17      Objeto17       Jardín  454.36        50  Proveedor2
# 2        23    Producto23        Hogar  469.00        81  Proveedor1
# 3        36    Artículo36         Moda  459.70        56  Proveedor2
# 4        37    Producto37         Moda  490.09        41  Proveedor3
# ...     ...           ...          ...     ...       ...         ...
# 2481  24931  Artículo9930  Electrónica  479.00        70  Proveedor3
# 2482  24934  Producto9933       Jardín  497.58        84  Proveedor3
# 2483  24937    Objeto9936        Hogar  497.92        49  Proveedor2
# 2484  24951  Producto9950       Jardín  458.40        67  Proveedor1
# 2485  24987  Producto9986         Moda  471.04        52  Proveedor3
#
#      fecha_ingreso  ubicacion
# 0       2023-06-27  Almacén B
# 1       2023-07-01  Almacén A
# 2       2023-03-18  Almacén C
# 3       2023-06-13  Almacén A
# 4       2023-01-23  Almacén C
# ...            ...        ...
# 2481    2023-08-13  Almacén C
# 2482    2023-10-08  Almacén A
# 2483    2023-12-04  Almacén C
# 2484    2023-12-20  Almacén A
# 2485    2023-04-20  Almacén C
#
# [2486 rows x 8 columns]

# %%
df_productos.head()
# Out:
#    id      nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0  12  Artículo12     Hogar  479.09        78  Proveedor3    2023-06-27
# 1  17    Objeto17    Jardín  454.36        50  Proveedor2    2023-07-01
# 2  23  Producto23     Hogar  469.00        81  Proveedor1    2023-03-18
# 3  36  Artículo36      Moda  459.70        56  Proveedor2    2023-06-13
# 4  37  Producto37      Moda  490.09        41  Proveedor3    2023-01-23
#
#    ubicacion
# 0  Almacén B
# 1  Almacén A
# 2  Almacén C
# 3  Almacén A
# 4  Almacén C

# %% [markdown]
# ## Nueva consulta

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450 AND cantidad > 25"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#          id        nombre    categoria  precio  cantidad   proveedor  \
# 0        12    Artículo12        Hogar  479.09        78  Proveedor3
# 1        17      Objeto17       Jardín  454.36        50  Proveedor2
# 2        23    Producto23        Hogar  469.00        81  Proveedor1
# 3        36    Artículo36         Moda  459.70        56  Proveedor2
# 4        37    Producto37         Moda  490.09        41  Proveedor3
# ...     ...           ...          ...     ...       ...         ...
# 1872  24931  Artículo9930  Electrónica  479.00        70  Proveedor3
# 1873  24934  Producto9933       Jardín  497.58        84  Proveedor3
# 1874  24937    Objeto9936        Hogar  497.92        49  Proveedor2
# 1875  24951  Producto9950       Jardín  458.40        67  Proveedor1
# 1876  24987  Producto9986         Moda  471.04        52  Proveedor3
#
#      fecha_ingreso  ubicacion
# 0       2023-06-27  Almacén B
# 1       2023-07-01  Almacén A
# 2       2023-03-18  Almacén C
# 3       2023-06-13  Almacén A
# 4       2023-01-23  Almacén C
# ...            ...        ...
# 1872    2023-08-13  Almacén C
# 1873    2023-10-08  Almacén A
# 1874    2023-12-04  Almacén C
# 1875    2023-12-20  Almacén A
# 1876    2023-04-20  Almacén C
#
# [1877 rows x 8 columns]

# %% [markdown]
# ## Insertar nuevo producto

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %% [markdown]
# ## Insertar nuevo producto desde Excel

# %% [markdown]
# ### Crear tabla excel de nuevos productos

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-07 08:25:47.160895  Almacén B
# 1 2025-03-12 08:25:47.160936  Almacén C
# 2 2024-12-18 08:25:47.160949  Almacén B
# 3 2025-08-15 08:25:47.160960  Almacén A
# 4 2024-12-01 08:25:47.160970  Almacén A

# %% [markdown]
# ### Agregar datos de tabla excel al inventario

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-07 08:25:47.161  Almacén B
# 1 2025-03-12 08:25:47.161  Almacén C
# 2 2024-12-18 08:25:47.161  Almacén B
# 3 2025-08-15 08:25:47.161  Almacén A
# 4 2024-12-01 08:25:47.161  Almacén A

# %%
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Preparar e insertar datos
for index, row in df.iterrows():
    c.execute("""
        INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
        VALUES (?, ?, ?, ?, ?, ?, ?)""",
        (
            row['Nombre'],
            row['Categoría'],
            float(row['Precio']),
            int(row['Cantidad']),
            row.get('Proveedor', None),
            row['Fecha de Ingreso'].strftime('%Y-%m-%d') if pd.notna(row['Fecha de Ingreso']) else None,
            row.get('Ubicación', None)
        )
    )

# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ¡Datos importados exitosamente!
